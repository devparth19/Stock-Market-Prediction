# %%
import sys
import subprocess
import importlib
import re

requirements_text = """
absl-py>=2.1.0
alembic>=1.14.0
annotated-types>=0.7.0
anyio>=4.6.2
argon2-cffi>=23.1.0
argon2-cffi-bindings>=21.2.0
arrow>=1.3.0
asttokens>=3.0.0
astunparse>=1.6.3
async-lru>=2.0.4
attrs>=24.2.0
babel>=2.16.0
beautifulsoup4>=4.12.3
bleach>=6.2.0
certifi>=2024.8.30
cffi>=1.15.1
charset-normalizer>=3.4.0
click>=8.1.7
colorama>=0.4.6
colorlog>=6.9.0
comm>=0.2.2
contourpy>=1.3.1
cycler>=0.12.1
debugpy>=1.8.9
decorator>=5.1.1
defusedxml>=0.7.1
executing>=1.0.0
fastapi>=0.115.6
fastjsonschema>=2.21.1
flatbuffers>=24.3.25
fonttools>=4.55.1
fqdn>=1.5.1
frozendict>=2.4.6
gast>=0.6.0
google-pasta>=0.2.0
greenlet>=3.1.1
grpcio>=1.68.1
h11>=0.14.0
h5py>=3.12.1
html5lib>=1.1
httpcore>=1.0.7
httpx>=0.28.0
idna>=3.10
ipykernel>=6.29.5
ipython>=8.30.0
isoduration>=20.11.0
jedi>=0.19.2
Jinja2>=3.1.4
joblib>=1.4.2
json5>=0.10.0
jsonpointer>=3.0.0
jsonschema>=4.23.0
jsonschema-specifications>=2024.10.1
jupyter-events>=0.10.0
jupyter-lsp>=2.2.5
jupyter_client>=8.6.3
jupyter_core>=5.7.2
jupyter_server>=2.14.2
jupyter_server_terminals>=0.5.3
jupyterlab>=4.2.6
jupyterlab_pygments>=0.3.0
jupyterlab_server>=2.27.3
keras>=3.7.0
kiwisolver>=1.4.7
libclang>=18.1.1
lxml>=5.3.0
Mako>=1.3.8
Markdown>=3.7
markdown-it-py>=3.0.0
MarkupSafe>=3.0.2
matplotlib>=3.9.3
matplotlib-inline>=0.1.7
mdurl>=0.1.2
mistune>=3.0.2
ml-dtypes>=0.4.1
multitasking>=0.0.11
namex>=0.0.8
nbclient>=0.10.1
nbconvert>=7.16.4
nbformat>=5.10.4
nest-asyncio>=1.6.0
notebook>=7.2.2
notebook_shim>=0.2.4
numpy>=2.0.2
opt_einsum>=3.4.0
optree>=0.13.1
optuna>=4.1.0
overrides>=7.7.0
packaging>=24.2
pandas>=2.2.3
pandocfilters>=1.5.1
parso>=0.8.4
patsy>=1.0.1
peewee>=3.17.8
pillow>=11.0.0
platformdirs>=4.3.6
prometheus_client>=0.21.1
prompt_toolkit>=3.0.48
protobuf>=5.29.0
psutil>=6.1.0
pure_eval>=0.2.3
pycparser>=2.22
pydantic>=2.10.3
pydantic_core>=2.27.1
Pygments>=2.18.0
pyparsing>=3.2.0
python-dateutil>=2.9.0
python-json-logger>=2.0.7
pytz>=2024.2
PyYAML>=6.0.2
pyzmq>=26.2.0
referencing>=0.35.1
requests>=2.32.3
rfc3339-validator>=0.1.4
rfc3986-validator>=0.1.1
rich>=13.9.4
rpds-py>=0.22.0
scikit-learn>=1.6.0
scipy>=1.14.1
seaborn>=0.13.2
Send2Trash>=1.8.3
six>=1.16.0
sniffio>=1.3.1
soupsieve>=2.6
SQLAlchemy>=2.0.36
stack-data>=0.6.3
starlette>=0.41.3
statsmodels>=0.14.4
tensorboard>=2.18.0
tensorboard-data-server>=0.7.2
tensorflow>=2.18.0
tensorflow-io-gcs-filesystem>=0.31.0
termcolor>=2.5.0
terminado>=0.18.1
threadpoolctl>=3.5.0
tinycss2>=1.4.0
tornado>=6.4.2
tqdm>=4.67.1
traitlets>=5.14.3
types-python-dateutil>=2.9.0
typing_extensions>=4.12.2
tzdata>=2024.2
uri-template>=1.3.0
urllib3>=2.2.3
uvicorn>=0.34.0
wcwidth>=0.2.13
webcolors>=24.11.1
webencodings>=0.5.1
websocket-client>=1.8.0
Werkzeug>=3.1.3
wrapt>=1.17.0
yfinance>=0.2.50
"""

# some packages have different import names
IMPORT_NAME_OVERRIDES = {
    "scikit-learn": "sklearn",
    "argon2-cffi": "argon2",
    "tensorboard-data-server": "tensorboard_data_server",
    "tensorflow-io-gcs-filesystem": "tensorflow_io_gcs_filesystem",
}

def parse_requirement(line):
    line = line.strip()
    if not line or line.startswith("#"):
        return None
    # split on version operator
    m = re.split(r'(>=|==|<=|~=|!=)', line, 1)
    if len(m) == 1:
        pkg = m[0].strip()
        return pkg, None, None
    else:
        pkg = m[0].strip()
        op = m[1]
        ver = m[2].strip()
        return pkg, op, ver

def get_import_name(pkg_name):
    if pkg_name in IMPORT_NAME_OVERRIDES:
        return IMPORT_NAME_OVERRIDES[pkg_name]
    return pkg_name.replace("-", "_")

def is_installed(import_name):
    try:
        importlib.import_module(import_name)
        return True
    except ImportError:
        return False

def pip_install(spec):
    print(f"\n>>> Installing: {spec}")
    try:
        subprocess.check_call([sys.executable, "-m", "pip", "install", spec])
        print(f"✓ Installed {spec}")
    except Exception as e:
        print(f"✗ Failed to install {spec}: {e}")

for line in requirements_text.strip().splitlines():
    parsed = parse_requirement(line)
    if not parsed:
        continue
    pkg, op, ver = parsed
    import_name = get_import_name(pkg)
    spec = pkg if not op else f"{pkg}{op}{ver}"

    print(f"\nChecking {pkg} (import as '{import_name}') ...")
    if is_installed(import_name):
        print(f"✓ Already installed")
    else:
        print(f"• Not installed, installing {spec}")
        pip_install(spec)

print("\nAll done.")
# Out:
# Checking absl-py (import as 'absl_py') ...
# • Not installed, installing absl-py>=2.1.0
#
# >>> Installing: absl-py>=2.1.0
# ✓ Installed absl-py>=2.1.0
#
# Checking alembic (import as 'alembic') ...
# • Not installed, installing alembic>=1.14.0
#
# >>> Installing: alembic>=1.14.0
# ✓ Installed alembic>=1.14.0
#
# Checking annotated-types (import as 'annotated_types') ...
# • Not installed, installing annotated-types>=0.7.0
#
# >>> Installing: annotated-types>=0.7.0
# ✓ Installed annotated-types>=0.7.0
#
# Checking anyio (import as 'anyio') ...
# • Not installed, installing anyio>=4.6.2
#
# >>> Installing: anyio>=4.6.2
# ✓ Installed anyio>=4.6.2
#
# Checking argon2-cffi (import as 'argon2') ...
# • Not installed, installing argon2-cffi>=23.1.0
#
# >>> Installing: argon2-cffi>=23.1.0
# ✓ Installed argon2-cffi>=23.1.0
#
# Checking argon2-cffi-bindings (import as 'argon2_cffi_bindings') ...
# • Not installed, installing argon2-cffi-bindings>=21.2.0
#
# >>> Installing: argon2-cffi-bindings>=21.2.0
# ✓ Installed argon2-cffi-bindings>=21.2.0
#
# Checking arrow (import as 'arrow') ...
# • Not installed, installing arrow>=1.3.0
#
# >>> Installing: arrow>=1.3.0
# ✓ Installed arrow>=1.3.0
#
# Checking asttokens (import as 'asttokens') ...
# ✓ Already installed
#
# Checking astunparse (import as 'astunparse') ...
# • Not installed, installing astunparse>=1.6.3
#
# >>> Installing: astunparse>=1.6.3
# ✓ Installed astunparse>=1.6.3
#
# Checking async-lru (import as 'async_lru') ...
# • Not installed, installing async-lru>=2.0.4
#
# >>> Installing: async-lru>=2.0.4
# ✓ Installed async-lru>=2.0.4
#
# Checking attrs (import as 'attrs') ...
# ✓ Already installed
#
# Checking babel (import as 'babel') ...
# • Not installed, installing babel>=2.16.0
#
# >>> Installing: babel>=2.16.0
# ✓ Installed babel>=2.16.0
#
# Checking beautifulsoup4 (import as 'beautifulsoup4') ...
# • Not installed, installing beautifulsoup4>=4.12.3
#
# >>> Installing: beautifulsoup4>=4.12.3
# ✓ Installed beautifulsoup4>=4.12.3
#
# Checking bleach (import as 'bleach') ...
# • Not installed, installing bleach>=6.2.0
#
# >>> Installing: bleach>=6.2.0
# ✓ Installed bleach>=6.2.0
#
# Checking certifi (import as 'certifi') ...
# • Not installed, installing certifi>=2024.8.30
#
# >>> Installing: certifi>=2024.8.30
# ✓ Installed certifi>=2024.8.30
#
# Checking cffi (import as 'cffi') ...
# ✓ Already installed
#
# Checking charset-normalizer (import as 'charset_normalizer') ...
# • Not installed, installing charset-normalizer>=3.4.0
#
# >>> Installing: charset-normalizer>=3.4.0
# ✓ Installed charset-normalizer>=3.4.0
#
# Checking click (import as 'click') ...
# • Not installed, installing click>=8.1.7
#
# >>> Installing: click>=8.1.7
# ✓ Installed click>=8.1.7
#
# Checking colorama (import as 'colorama') ...
# ✓ Already installed
#
# Checking colorlog (import as 'colorlog') ...
# • Not installed, installing colorlog>=6.9.0
#
# >>> Installing: colorlog>=6.9.0
# ✓ Installed colorlog>=6.9.0
#
# Checking comm (import as 'comm') ...
# ✓ Already installed
#
# Checking contourpy (import as 'contourpy') ...
# ✓ Already installed
#
# Checking cycler (import as 'cycler') ...
# ✓ Already installed
#
# Checking debugpy (import as 'debugpy') ...
# ✓ Already installed
#
# Checking decorator (import as 'decorator') ...
# ✓ Already installed
#
# Checking defusedxml (import as 'defusedxml') ...
# • Not installed, installing defusedxml>=0.7.1
#
# >>> Installing: defusedxml>=0.7.1
# ✓ Installed defusedxml>=0.7.1
#
# Checking executing (import as 'executing') ...
# ✓ Already installed
#
# Checking fastapi (import as 'fastapi') ...
# • Not installed, installing fastapi>=0.115.6
#
# >>> Installing: fastapi>=0.115.6
# ✓ Installed fastapi>=0.115.6
#
# Checking fastjsonschema (import as 'fastjsonschema') ...
# • Not installed, installing fastjsonschema>=2.21.1
#
# >>> Installing: fastjsonschema>=2.21.1
# ✓ Installed fastjsonschema>=2.21.1
#
# Checking flatbuffers (import as 'flatbuffers') ...
# ✓ Already installed
#
# Checking fonttools (import as 'fonttools') ...
# • Not installed, installing fonttools>=4.55.1
#
# >>> Installing: fonttools>=4.55.1
# ✓ Installed fonttools>=4.55.1
#
# Checking fqdn (import as 'fqdn') ...
# • Not installed, installing fqdn>=1.5.1
#
# >>> Installing: fqdn>=1.5.1
# ✓ Installed fqdn>=1.5.1
#
# Checking frozendict (import as 'frozendict') ...
# • Not installed, installing frozendict>=2.4.6
#
# >>> Installing: frozendict>=2.4.6
# ✓ Installed frozendict>=2.4.6
#
# Checking gast (import as 'gast') ...
# • Not installed, installing gast>=0.6.0
#
# >>> Installing: gast>=0.6.0
# ✓ Installed gast>=0.6.0
#
# Checking google-pasta (import as 'google_pasta') ...
# • Not installed, installing google-pasta>=0.2.0
#
# >>> Installing: google-pasta>=0.2.0
# ✓ Installed google-pasta>=0.2.0
#
# Checking greenlet (import as 'greenlet') ...
# ✓ Already installed
#
# Checking grpcio (import as 'grpcio') ...
# • Not installed, installing grpcio>=1.68.1
#
# >>> Installing: grpcio>=1.68.1
# ✓ Installed grpcio>=1.68.1
#
# Checking h11 (import as 'h11') ...
# • Not installed, installing h11>=0.14.0
#
# >>> Installing: h11>=0.14.0
# ✓ Installed h11>=0.14.0
#
# Checking h5py (import as 'h5py') ...
# • Not installed, installing h5py>=3.12.1
#
# >>> Installing: h5py>=3.12.1
# ✓ Installed h5py>=3.12.1
#
# Checking html5lib (import as 'html5lib') ...
# • Not installed, installing html5lib>=1.1
#
# >>> Installing: html5lib>=1.1
# ✓ Installed html5lib>=1.1
#
# Checking httpcore (import as 'httpcore') ...
# • Not installed, installing httpcore>=1.0.7
#
# >>> Installing: httpcore>=1.0.7
# ✓ Installed httpcore>=1.0.7
#
# Checking httpx (import as 'httpx') ...
# • Not installed, installing httpx>=0.28.0
#
# >>> Installing: httpx>=0.28.0
# ✓ Installed httpx>=0.28.0
#
# Checking idna (import as 'idna') ...
# ✓ Already installed
#
# Checking ipykernel (import as 'ipykernel') ...
# ✓ Already installed
#
# Checking ipython (import as 'ipython') ...
# • Not installed, installing ipython>=8.30.0
#
# >>> Installing: ipython>=8.30.0
# ✓ Installed ipython>=8.30.0
#
# Checking isoduration (import as 'isoduration') ...
# • Not installed, installing isoduration>=20.11.0
#
# >>> Installing: isoduration>=20.11.0
# ✓ Installed isoduration>=20.11.0
#
# Checking jedi (import as 'jedi') ...
# ✓ Already installed
#
# Checking Jinja2 (import as 'Jinja2') ...
# • Not installed, installing Jinja2>=3.1.4
#
# >>> Installing: Jinja2>=3.1.4
# ✓ Installed Jinja2>=3.1.4
#
# Checking joblib (import as 'joblib') ...
# • Not installed, installing joblib>=1.4.2
#
# >>> Installing: joblib>=1.4.2
# ✓ Installed joblib>=1.4.2
#
# Checking json5 (import as 'json5') ...
# • Not installed, installing json5>=0.10.0
#
# >>> Installing: json5>=0.10.0
# ✓ Installed json5>=0.10.0
#
# Checking jsonpointer (import as 'jsonpointer') ...
# • Not installed, installing jsonpointer>=3.0.0
#
# >>> Installing: jsonpointer>=3.0.0
# ✓ Installed jsonpointer>=3.0.0
#
# Checking jsonschema (import as 'jsonschema') ...
# • Not installed, installing jsonschema>=4.23.0
#
# >>> Installing: jsonschema>=4.23.0
# ✓ Installed jsonschema>=4.23.0
#
# Checking jsonschema-specifications (import as 'jsonschema_specifications') ...
# ✓ Already installed
#
# Checking jupyter-events (import as 'jupyter_events') ...
# • Not installed, installing jupyter-events>=0.10.0
#
# >>> Installing: jupyter-events>=0.10.0
# ✓ Installed jupyter-events>=0.10.0
#
# Checking jupyter-lsp (import as 'jupyter_lsp') ...
# • Not installed, installing jupyter-lsp>=2.2.5
#
# >>> Installing: jupyter-lsp>=2.2.5
# ✓ Installed jupyter-lsp>=2.2.5
#
# Checking jupyter_client (import as 'jupyter_client') ...
# ✓ Already installed
#
# Checking jupyter_core (import as 'jupyter_core') ...
# ✓ Already installed
#
# Checking jupyter_server (import as 'jupyter_server') ...
# ✓ Already installed
#
# Checking jupyter_server_terminals (import as 'jupyter_server_terminals') ...
# ✓ Already installed
#
# Checking jupyterlab (import as 'jupyterlab') ...
# • Not installed, installing jupyterlab>=4.2.6
#
# >>> Installing: jupyterlab>=4.2.6
# ✓ Installed jupyterlab>=4.2.6
#
# Checking jupyterlab_pygments (import as 'jupyterlab_pygments') ...
# ✓ Already installed
#
# Checking jupyterlab_server (import as 'jupyterlab_server') ...
# ✓ Already installed
#
# Checking keras (import as 'keras') ...
# • Not installed, installing keras>=3.7.0
#
# >>> Installing: keras>=3.7.0
# ✓ Installed keras>=3.7.0
#
# Checking kiwisolver (import as 'kiwisolver') ...
# ✓ Already installed
#
# Checking libclang (import as 'libclang') ...
# • Not installed, installing libclang>=18.1.1
#
# >>> Installing: libclang>=18.1.1
# ✓ Installed libclang>=18.1.1
#
# Checking lxml (import as 'lxml') ...
# • Not installed, installing lxml>=5.3.0
#
# >>> Installing: lxml>=5.3.0
# ✓ Installed lxml>=5.3.0
#
# Checking Mako (import as 'Mako') ...
# • Not installed, installing Mako>=1.3.8
#
# >>> Installing: Mako>=1.3.8
# ✓ Installed Mako>=1.3.8
#
# Checking Markdown (import as 'Markdown') ...
# • Not installed, installing Markdown>=3.7
#
# >>> Installing: Markdown>=3.7
# ✓ Installed Markdown>=3.7
#
# Checking markdown-it-py (import as 'markdown_it_py') ...
# • Not installed, installing markdown-it-py>=3.0.0
#
# >>> Installing: markdown-it-py>=3.0.0
# ✓ Installed markdown-it-py>=3.0.0
#
# Checking MarkupSafe (import as 'MarkupSafe') ...
# • Not installed, installing MarkupSafe>=3.0.2
#
# >>> Installing: MarkupSafe>=3.0.2
# ✓ Installed MarkupSafe>=3.0.2
#
# Checking matplotlib (import as 'matplotlib') ...
# ✓ Already installed
#
# Checking matplotlib-inline (import as 'matplotlib_inline') ...
# ✓ Already installed
#
# Checking mdurl (import as 'mdurl') ...
# ✓ Already installed
#
# Checking mistune (import as 'mistune') ...
# ✓ Already installed
#
# Checking ml-dtypes (import as 'ml_dtypes') ...
# ✓ Already installed
#
# Checking multitasking (import as 'multitasking') ...
# • Not installed, installing multitasking>=0.0.11
#
# >>> Installing: multitasking>=0.0.11
# ✓ Installed multitasking>=0.0.11
#
# Checking namex (import as 'namex') ...
# ✓ Already installed
#
# Checking nbclient (import as 'nbclient') ...
# ✓ Already installed
#
# Checking nbconvert (import as 'nbconvert') ...
# ✓ Already installed
#
# Checking nbformat (import as 'nbformat') ...
# ✓ Already installed
#
# Checking nest-asyncio (import as 'nest_asyncio') ...
# ✓ Already installed
#
# Checking notebook (import as 'notebook') ...
# • Not installed, installing notebook>=7.2.2
#
# >>> Installing: notebook>=7.2.2
# ✓ Installed notebook>=7.2.2
#
# Checking notebook_shim (import as 'notebook_shim') ...
# ✓ Already installed
#
# Checking numpy (import as 'numpy') ...
# ✓ Already installed
#
# Checking opt_einsum (import as 'opt_einsum') ...
# ✓ Already installed
#
# Checking optree (import as 'optree') ...
# ✓ Already installed
#
# Checking optuna (import as 'optuna') ...
# • Not installed, installing optuna>=4.1.0
#
# >>> Installing: optuna>=4.1.0
# ✓ Installed optuna>=4.1.0
#
# Checking overrides (import as 'overrides') ...
# • Not installed, installing overrides>=7.7.0
#
# >>> Installing: overrides>=7.7.0
# ✓ Installed overrides>=7.7.0
#
# Checking packaging (import as 'packaging') ...
# ✓ Already installed
#
# Checking pandas (import as 'pandas') ...
# • Not installed, installing pandas>=2.2.3
#
# >>> Installing: pandas>=2.2.3
# ✓ Installed pandas>=2.2.3
#
# Checking pandocfilters (import as 'pandocfilters') ...
# ✓ Already installed
#
# Checking parso (import as 'parso') ...
# ✓ Already installed
#
# Checking patsy (import as 'patsy') ...
# • Not installed, installing patsy>=1.0.1
#
# >>> Installing: patsy>=1.0.1
# ✓ Installed patsy>=1.0.1
#
# Checking peewee (import as 'peewee') ...
# • Not installed, installing peewee>=3.17.8
#
# >>> Installing: peewee>=3.17.8
# ✓ Installed peewee>=3.17.8
#
# Checking pillow (import as 'pillow') ...
# • Not installed, installing pillow>=11.0.0
#
# >>> Installing: pillow>=11.0.0
# ✓ Installed pillow>=11.0.0
#
# Checking platformdirs (import as 'platformdirs') ...
# ✓ Already installed
#
# Checking prometheus_client (import as 'prometheus_client') ...
# ✓ Already installed
#
# Checking prompt_toolkit (import as 'prompt_toolkit') ...
# ✓ Already installed
#
# Checking protobuf (import as 'protobuf') ...
# • Not installed, installing protobuf>=5.29.0
#
# >>> Installing: protobuf>=5.29.0
# ✓ Installed protobuf>=5.29.0
#
# Checking psutil (import as 'psutil') ...
# ✓ Already installed
#
# Checking pure_eval (import as 'pure_eval') ...
# ✓ Already installed
#
# Checking pycparser (import as 'pycparser') ...
# ✓ Already installed
#
# Checking pydantic (import as 'pydantic') ...
# ✓ Already installed
#
# Checking pydantic_core (import as 'pydantic_core') ...
# ✓ Already installed
#
# Checking Pygments (import as 'Pygments') ...
# • Not installed, installing Pygments>=2.18.0
#
# >>> Installing: Pygments>=2.18.0
# ✓ Installed Pygments>=2.18.0
#
# Checking pyparsing (import as 'pyparsing') ...
# ✓ Already installed
#
# Checking python-dateutil (import as 'python_dateutil') ...
# • Not installed, installing python-dateutil>=2.9.0
#
# >>> Installing: python-dateutil>=2.9.0
# ✓ Installed python-dateutil>=2.9.0
#
# Checking python-json-logger (import as 'python_json_logger') ...
# • Not installed, installing python-json-logger>=2.0.7
#
# >>> Installing: python-json-logger>=2.0.7
# ✓ Installed python-json-logger>=2.0.7
#
# Checking pytz (import as 'pytz') ...
# ✓ Already installed
#
# Checking PyYAML (import as 'PyYAML') ...
# • Not installed, installing PyYAML>=6.0.2
#
# >>> Installing: PyYAML>=6.0.2
# ✓ Installed PyYAML>=6.0.2
#
# Checking pyzmq (import as 'pyzmq') ...
# • Not installed, installing pyzmq>=26.2.0
#
# >>> Installing: pyzmq>=26.2.0
# ✓ Installed pyzmq>=26.2.0
#
# Checking referencing (import as 'referencing') ...
# ✓ Already installed
#
# Checking requests (import as 'requests') ...
# ✓ Already installed
#
# Checking rfc3339-validator (import as 'rfc3339_validator') ...
# ✓ Already installed
#
# Checking rfc3986-validator (import as 'rfc3986_validator') ...
# ✓ Already installed
#
# Checking rich (import as 'rich') ...
# ✓ Already installed
#
# Checking rpds-py (import as 'rpds_py') ...
# • Not installed, installing rpds-py>=0.22.0
#
# >>> Installing: rpds-py>=0.22.0
# ✓ Installed rpds-py>=0.22.0
#
# Checking scikit-learn (import as 'sklearn') ...
# • Not installed, installing scikit-learn>=1.6.0
#
# >>> Installing: scikit-learn>=1.6.0
# ✓ Installed scikit-learn>=1.6.0
#
# Checking scipy (import as 'scipy') ...
# ✓ Already installed
#
# Checking seaborn (import as 'seaborn') ...
# • Not installed, installing seaborn>=0.13.2
#
# >>> Installing: seaborn>=0.13.2
# ✓ Installed seaborn>=0.13.2
#
# Checking Send2Trash (import as 'Send2Trash') ...
# • Not installed, installing Send2Trash>=1.8.3
#
# >>> Installing: Send2Trash>=1.8.3
# ✓ Installed Send2Trash>=1.8.3
#
# Checking six (import as 'six') ...
# ✓ Already installed
#
# Checking sniffio (import as 'sniffio') ...
# ✓ Already installed
#
# Checking soupsieve (import as 'soupsieve') ...
# ✓ Already installed
#
# Checking SQLAlchemy (import as 'SQLAlchemy') ...
# • Not installed, installing SQLAlchemy>=2.0.36
#
# >>> Installing: SQLAlchemy>=2.0.36
# ✓ Installed SQLAlchemy>=2.0.36
#
# Checking stack-data (import as 'stack_data') ...
# ✓ Already installed
#
# Checking starlette (import as 'starlette') ...
# ✓ Already installed
#
# Checking statsmodels (import as 'statsmodels') ...
# • Not installed, installing statsmodels>=0.14.4
#
# >>> Installing: statsmodels>=0.14.4
# ✓ Installed statsmodels>=0.14.4
#
# Checking tensorboard (import as 'tensorboard') ...
# • Not installed, installing tensorboard>=2.18.0
#
# >>> Installing: tensorboard>=2.18.0
# ✓ Installed tensorboard>=2.18.0
#
# Checking tensorboard-data-server (import as 'tensorboard_data_server') ...
# ✓ Already installed
#
# Checking tensorflow (import as 'tensorflow') ...
# • Not installed, installing tensorflow>=2.18.0
#
# >>> Installing: tensorflow>=2.18.0
# ✓ Installed tensorflow>=2.18.0
#
# Checking tensorflow-io-gcs-filesystem (import as 'tensorflow_io_gcs_filesystem') ...
# • Not installed, installing tensorflow-io-gcs-filesystem>=0.31.0
#
# >>> Installing: tensorflow-io-gcs-filesystem>=0.31.0
# ✗ Failed to install tensorflow-io-gcs-filesystem>=0.31.0: Command '['C:\\Users\\parth\\mp_env\\Scripts\\python.exe', '-m', 'pip', 'install', 'tensorflow-io-gcs-filesystem>=0.31.0']' returned non-zero exit status 1.
#
# Checking termcolor (import as 'termcolor') ...
# ✓ Already installed
#
# Checking terminado (import as 'terminado') ...
# ✓ Already installed
#
# Checking threadpoolctl (import as 'threadpoolctl') ...
# ✓ Already installed
#
# Checking tinycss2 (import as 'tinycss2') ...
# ✓ Already installed
#
# Checking tornado (import as 'tornado') ...
# ✓ Already installed
#
# Checking tqdm (import as 'tqdm') ...
# ✓ Already installed
#
# Checking traitlets (import as 'traitlets') ...
# ✓ Already installed
#
# Checking types-python-dateutil (import as 'types_python_dateutil') ...
# • Not installed, installing types-python-dateutil>=2.9.0
#
# >>> Installing: types-python-dateutil>=2.9.0
# ✓ Installed types-python-dateutil>=2.9.0
#
# Checking typing_extensions (import as 'typing_extensions') ...
# ✓ Already installed
#
# Checking tzdata (import as 'tzdata') ...
# ✓ Already installed
#
# Checking uri-template (import as 'uri_template') ...
# ✓ Already installed
# Checking urllib3 (import as 'urllib3') ...
# ✓ Already installed
#
# Checking uvicorn (import as 'uvicorn') ...
# • Not installed, installing uvicorn>=0.34.0
#
# >>> Installing: uvicorn>=0.34.0
# ✓ Installed uvicorn>=0.34.0
#
# Checking wcwidth (import as 'wcwidth') ...
# ✓ Already installed
#
# Checking webcolors (import as 'webcolors') ...
# ✓ Already installed
#
# Checking webencodings (import as 'webencodings') ...
# ✓ Already installed
#
# Checking websocket-client (import as 'websocket_client') ...
# • Not installed, installing websocket-client>=1.8.0
#
# >>> Installing: websocket-client>=1.8.0
# ✓ Installed websocket-client>=1.8.0
#
# Checking Werkzeug (import as 'Werkzeug') ...
# • Not installed, installing Werkzeug>=3.1.3
#
# >>> Installing: Werkzeug>=3.1.3
# ✓ Installed Werkzeug>=3.1.3
#
# Checking wrapt (import as 'wrapt') ...
# ✓ Already installed
#
# Checking yfinance (import as 'yfinance') ...
# • Not installed, installing yfinance>=0.2.50
#
# >>> Installing: yfinance>=0.2.50
# ✓ Installed yfinance>=0.2.50
#
# All done.
