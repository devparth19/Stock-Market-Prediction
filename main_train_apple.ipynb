# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, SimpleRNN, Dropout
from sklearn.preprocessing import MinMaxScaler
import joblib  # For saving the scaler
import os
import pandas as pd
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
import tensorflow.lite as tflite
import random
import os
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import pickle





SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
os.environ['TF_DETERMINISTIC_OPS'] = '1'
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'





def preprocess_stock_data(
    csv_path, 
    date_column='Date', 
    close_column='Close', 
    test_size=0.2, 
    validation_size=0.1,
    time_steps=60, 
    scaler_output_file='outputs/apple_scale.pkl'
):
    """
    Prepares stock market price data for time series modeling, with training, validation, and test splits.

    Args:
        csv_path (str): Path to the CSV file containing the data.
        date_column (str): Name of the date column in the CSV.
        close_column (str): Name of the closing price column in the CSV.
        test_size (float): Proportion of the data for testing.
        validation_size (float): Proportion of the data for validation.
        time_steps (int): Number of past time steps to use for each sample.
        scaler_output_file (str): Path to save the fitted MinMaxScaler instance.

    Returns:
        X_train (numpy.ndarray): Training data (features).
        y_train (numpy.ndarray): Training labels.
        X_val (numpy.ndarray): Validation data (features).
        y_val (numpy.ndarray): Validation labels.
        X_test (numpy.ndarray): Testing data (features).
        y_test (numpy.ndarray): Testing labels.
    """
    try:
        # Load the dataset
        if not os.path.exists(csv_path):
            raise FileNotFoundError(f"CSV file not found at path: {csv_path}")

        data = pd.read_csv(csv_path, parse_dates=[date_column])
        data.sort_values(by=date_column, inplace=True)

        print(f"CSV file successfully loaded. Columns: {data.columns}")
    except Exception as e:
        raise ValueError(f"Error reading CSV file or parsing date column '{date_column}': {e}")
    
    # Validate columns
    if date_column not in data.columns or close_column not in data.columns:
        raise ValueError(f"Columns '{date_column}' or '{close_column}' not found in dataset. Available columns: {data.columns}")

    try:
        # Extract the 'close' column for scaling
        close_prices = data[close_column].values.reshape(-1, 1)
    except Exception as e:
        raise ValueError(f"Error accessing '{close_column}' column: {e}")
    
    # Scale the data
    try:
        scaler = MinMaxScaler(feature_range=(0, 1))
        scaled_close = scaler.fit_transform(close_prices)

        # Save the scaler to a file
        with open(scaler_output_file, 'wb') as f:
            pickle.dump(scaler, f)
        print(f"Scaler saved to {scaler_output_file}")
    except Exception as e:
        raise IOError(f"Error during scaling or saving scaler: {e}")
    
    # Create sequences of time_steps
    X, y = [], []
    try:
        for i in range(time_steps, len(scaled_close)):
            X.append(scaled_close[i - time_steps:i])
            y.append(scaled_close[i])
    except Exception as e:
        raise ValueError(f"Error creating sequences of time_steps: {e}")
    
    X, y = np.array(X), np.array(y)
    
    # Split data into train, validation, and test sets
    try:
        total_size = len(X)
        test_size_count = int(test_size * total_size)
        validation_size_count = int(validation_size * total_size)

        train_end_idx = total_size - test_size_count - validation_size_count
        val_end_idx = total_size - test_size_count

        X_train, X_val, X_test = X[:train_end_idx], X[train_end_idx:val_end_idx], X[val_end_idx:]
        y_train, y_val, y_test = y[:train_end_idx], y[train_end_idx:val_end_idx], y[val_end_idx:]

        # Adjust splits to match desired sample sizes
        train_samples = 554
        val_samples = 55
        test_samples = 84

        X_train, y_train = X[:train_samples], y[:train_samples]
        X_val, y_val = X[train_samples:train_samples + val_samples], y[train_samples:train_samples + val_samples]
        X_test, y_test = X[train_samples + val_samples:train_samples + val_samples + test_samples], y[train_samples + val_samples:train_samples + val_samples + test_samples]
    except Exception as e:
        raise ValueError(f"Error splitting data into train, validation, and test sets: {e}")
    
    print(f"Data split: {len(X_train)} training samples, {len(X_val)} validation samples, {len(X_test)} testing samples")
    
    return X_train, y_train, X_val, y_val, X_test, y_test






data = "inputs/apple_stock_cleaned.csv"


try:
    X_train, y_train, X_val, y_val, X_test, y_test = preprocess_stock_data(
        data, 
        date_column='Date', 
        close_column='Close', 
        test_size=0.2, 
        time_steps=60, 
        scaler_output_file='outputs/apple_scale.pkl'
    )

    # Outputs
    print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
    print(f"X_train shape: {X_val.shape}, y_train shape: {y_val.shape}")
    print(f"X_test shape: {X_test.shape}, y_test shape: {y_test.shape}")
except ValueError as ve:
    print(f"ValueError: {ve}")
except Exception as e:
    print(f"Unexpected Error: {e}")





print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)





from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import SimpleRNN, Dense, Dropout, LSTM, MultiHeadAttention, LayerNormalization
from tensorflow.keras.callbacks import EarlyStopping
import tensorflow as tf
import joblib
import numpy as np
import os

@tf.keras.utils.register_keras_serializable(package="Custom", name="symmetric_mean_absolute_percentage_error")
def symmetric_mean_absolute_percentage_error(y_true, y_pred):
    """
    Computes Symmetric Mean Absolute Percentage Error (SMAPE).

    Args:
        y_true: Ground truth values.
        y_pred: Predicted values.

    Returns:
        SMAPE as a TensorFlow tensor.
    """
    numerator = tf.abs(y_true - y_pred)
    denominator = (tf.abs(y_true) + tf.abs(y_pred)) / 2
    smape = tf.reduce_mean(numerator / denominator) * 100
    return smape


class StockPricePredictor_Apple:
    def __init__(self, input_shape, learning_rate=0.01341034226855941, num_layers=2, units=32):
        self.input_shape = input_shape  # Should be (time_steps, features)
        self.learning_rate = learning_rate
        self.num_layers = num_layers
        self.units = units
        self.model = self._build_model()

    def _build_model(self):
        model = Sequential()
        for i in range(self.num_layers):
            # Add LSTM layers
            return_sequences = i < (self.num_layers - 1)
            model.add(LSTM(self.units, activation='relu', return_sequences=return_sequences, input_shape=self.input_shape))
            model.add(Dropout(0.2))  # Regularization

        # Output layer for regression (single output: close value)
        model.add(Dense(1))

        # Compile the model
        model.compile(
            optimizer=tf.keras.optimizers.Adam(learning_rate=self.learning_rate),
            loss=tf.keras.losses.MeanSquaredError(),
            metrics=[
                tf.keras.metrics.MeanAbsoluteError(),
                tf.keras.metrics.MeanAbsolutePercentageError(),
                symmetric_mean_absolute_percentage_error  # Custom SMAPE metric
            ]
        )
        return model

    def train(self, X_train, y_train, batch_size=16, epochs=50, validation_data=None, patience=15):
        """
        Trains the model with an EarlyStopping callback.
        
        Args:
            X_train: Training input data.
            y_train: Training target data.
            batch_size: Batch size for training.
            epochs: Maximum number of training epochs.
            validation_data: Tuple (X_val, y_val) for validation.
            patience: Number of epochs with no improvement after which training will be stopped.
        
        Returns:
            History object containing training details.
        """
        X_train = self._validate_and_reshape(X_train, expected_shape=(None, *self.input_shape))
        if validation_data:
            X_val = self._validate_and_reshape(validation_data[0], expected_shape=(None, *self.input_shape))
            validation_data = (X_val, validation_data[1])

        early_stopping = EarlyStopping(
            monitor='val_loss',
            patience=patience,
            restore_best_weights=True
        )

        history = self.model.fit(
            X_train, y_train,
            batch_size=batch_size,
            epochs=epochs,
            validation_data=validation_data,
            callbacks=[early_stopping],
            verbose=2
        )
        return history

    def predict(self, X):
        X = self._validate_and_reshape(X, expected_shape=(None, *self.input_shape))
        return self.model.predict(X)

    def save(self, model_path):
        self.model.save(model_path)
        print(f"Model saved to {model_path}")

    @staticmethod
    def load(model_path, scaler_path):
        model = load_model(model_path, custom_objects={
            "symmetric_mean_absolute_percentage_error": symmetric_mean_absolute_percentage_error
        })
        print(f"Model loaded from {model_path}")

        scaler = joblib.load(scaler_path)
        print(f"Scaler loaded from {scaler_path}")

        return model, scaler

    def _validate_and_reshape(self, X, expected_shape):
        if len(X.shape) == 2:
            reshaped = X[..., np.newaxis]
            print(f"Reshaped input from {X.shape} to {reshaped.shape}")
            return reshaped
        elif len(X.shape) == len(expected_shape):
            print(f"Input shape is valid: {X.shape}")
            return X
        else:
            raise ValueError(f"Invalid input shape {X.shape}. Expected shape {expected_shape}.")









data_path_apple = "inputs/apple_stock_cleaned.csv"

#output_file = "scaled_stock_data_close_option.pkl"







if __name__ == "__main__":
    # Example input data
    input_shape = (60, 1)  # 60 time steps, 1 feature (e.g., close price)
    predictor = StockPricePredictor_Apple(input_shape=input_shape)

    # Training
    predictor.train(X_train, y_train, validation_data=(X_val, y_val))

    # Save the model
    model_path = "outputs/stock_price_lstm_apple_model.keras"
    scaler_path = "outputs/apple_scale.pkl"
    predictor.save(model_path)

    # Load model and scaler for inference
    loaded_model, loaded_scaler = StockPricePredictor_Apple.load(model_path, scaler_path)

    # Predict on test data
    predictions = loaded_model.predict(X_test)
    predictions_rescaled = loaded_scaler.inverse_transform(predictions).astype('float32')

    # Rescale test labels for evaluation (if scaled)
    y_test_rescaled = loaded_scaler.inverse_transform(y_test.reshape(-1, 1)).astype('float32')

    # Print predictions
    print("Predictions (rescaled):", predictions_rescaled.astype('float32'))

    # Evaluate metrics on test data
    metrics = loaded_model.evaluate(X_test, y_test, verbose=2)
    metric_names = loaded_model.metrics_names  # Get metric names for better interpretability

    # Display metrics
    for name, value in zip(metric_names, metrics):
        print(f"{name}: {value:.4f}")

    # Compute and display custom SMAPE manually for rescaled predictions
    smape_manual = symmetric_mean_absolute_percentage_error(y_test_rescaled, predictions_rescaled)
    print(f"SMAPE (manual, rescaled): {smape_manual.numpy():.4f}")





plt.figure(figsize=(12, 6))
plt.plot(loaded_scaler.inverse_transform(y_test.reshape(-1, 1)), label="Actual Prices", color="darkorange", alpha=0.6, linewidth=2)
plt.plot(loaded_scaler.inverse_transform(predictions.reshape(-1, 1)), label="Predicted Prices", color="#A3AAAE", alpha=0.6, linestyle="--", linewidth=2)
plt.title("Stock Price Prediction for Apple",fontsize = 26)
plt.xlabel("Time Steps",fontsize = 20)
plt.ylabel("Stock Price (Original Scale)",fontsize = 20)
plt.legend(fontsize = 20)
plt.grid(True)
plt.savefig('results/apple_result.png', bbox_inches='tight')
plt.show()
# Out:
# CSV file successfully loaded. Columns: Index(['Unnamed: 0', 'Date', 'Open', 'High', 'Low', 'Close', 'Adj Close',
#        'Volume', 'daily_return', '20_day_ma', '50_day_ma'],
#       dtype='object')
# Scaler saved to outputs/apple_scale.pkl
# Data split: 554 training samples, 55 validation samples, 84 testing samples
# X_train shape: (554, 60, 1), y_train shape: (554, 1)
# X_train shape: (55, 60, 1), y_train shape: (55, 1)
# X_test shape: (84, 60, 1), y_test shape: (84, 1)
# X_train shape: (554, 60, 1)
# y_train shape: (554, 1)
# Input shape is valid: (554, 60, 1)
# Input shape is valid: (55, 60, 1)
# C:\Users\parth\mp_env\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 35/35 - 6s - 173ms/step - loss: 0.1090 - mean_absolute_error: 0.2302 - mean_absolute_percentage_error: 69192.9688 - symmetric_mean_absolute_percentage_error: 76.6578 - val_loss: 0.0874 - val_mean_absolute_error: 0.2679 - val_mean_absolute_percentage_error: 43.3817 - val_symmetric_mean_absolute_percentage_error: 59.6005
# Epoch 2/50
# 35/35 - 1s - 37ms/step - loss: 0.0175 - mean_absolute_error: 0.1077 - mean_absolute_percentage_error: 613166.2500 - symmetric_mean_absolute_percentage_error: 34.4882 - val_loss: 0.0220 - val_mean_absolute_error: 0.1344 - val_mean_absolute_percentage_error: 22.2116 - val_symmetric_mean_absolute_percentage_error: 24.6379
# Epoch 3/50
# 35/35 - 1s - 41ms/step - loss: 0.0085 - mean_absolute_error: 0.0732 - mean_absolute_percentage_error: 386364.2188 - symmetric_mean_absolute_percentage_error: 24.7192 - val_loss: 0.0203 - val_mean_absolute_error: 0.1317 - val_mean_absolute_percentage_error: 22.2138 - val_symmetric_mean_absolute_percentage_error: 24.6307
# Epoch 4/50
# 35/35 - 2s - 47ms/step - loss: 0.0076 - mean_absolute_error: 0.0696 - mean_absolute_percentage_error: 381813.7500 - symmetric_mean_absolute_percentage_error: 23.8187 - val_loss: 0.0106 - val_mean_absolute_error: 0.0888 - val_mean_absolute_percentage_error: 14.5134 - val_symmetric_mean_absolute_percentage_error: 15.5875
# Epoch 5/50
# 35/35 - 1s - 42ms/step - loss: 0.0081 - mean_absolute_error: 0.0709 - mean_absolute_percentage_error: 382171.9688 - symmetric_mean_absolute_percentage_error: 24.0518 - val_loss: 0.0102 - val_mean_absolute_error: 0.0876 - val_mean_absolute_percentage_error: 14.4278 - val_symmetric_mean_absolute_percentage_error: 15.3987
# Epoch 6/50
# 35/35 - 2s - 44ms/step - loss: 0.0070 - mean_absolute_error: 0.0658 - mean_absolute_percentage_error: 368683.7500 - symmetric_mean_absolute_percentage_error: 23.0556 - val_loss: 0.0170 - val_mean_absolute_error: 0.1144 - val_mean_absolute_percentage_error: 18.4173 - val_symmetric_mean_absolute_percentage_error: 20.9461
# Epoch 7/50
# 35/35 - 2s - 44ms/step - loss: 0.0062 - mean_absolute_error: 0.0628 - mean_absolute_percentage_error: 370962.0938 - symmetric_mean_absolute_percentage_error: 21.8412 - val_loss: 0.0175 - val_mean_absolute_error: 0.1188 - val_mean_absolute_percentage_error: 19.5458 - val_symmetric_mean_absolute_percentage_error: 21.9936
# Epoch 8/50
# 35/35 - 2s - 46ms/step - loss: 0.0068 - mean_absolute_error: 0.0646 - mean_absolute_percentage_error: 362525.8125 - symmetric_mean_absolute_percentage_error: 22.2005 - val_loss: 0.0123 - val_mean_absolute_error: 0.1001 - val_mean_absolute_percentage_error: 16.9199 - val_symmetric_mean_absolute_percentage_error: 17.9841
# Epoch 9/50
# 35/35 - 1s - 41ms/step - loss: 0.0063 - mean_absolute_error: 0.0617 - mean_absolute_percentage_error: 370620.2812 - symmetric_mean_absolute_percentage_error: 21.7143 - val_loss: 0.0139 - val_mean_absolute_error: 0.1036 - val_mean_absolute_percentage_error: 16.8608 - val_symmetric_mean_absolute_percentage_error: 18.8052
# Epoch 10/50
# 35/35 - 1s - 37ms/step - loss: 0.0060 - mean_absolute_error: 0.0604 - mean_absolute_percentage_error: 356201.0000 - symmetric_mean_absolute_percentage_error: 21.2733 - val_loss: 0.0093 - val_mean_absolute_error: 0.0827 - val_mean_absolute_percentage_error: 13.5174 - val_symmetric_mean_absolute_percentage_error: 14.5685
# Epoch 11/50
# 35/35 - 2s - 43ms/step - loss: 0.0053 - mean_absolute_error: 0.0557 - mean_absolute_percentage_error: 344301.3438 - symmetric_mean_absolute_percentage_error: 19.8428 - val_loss: 0.0129 - val_mean_absolute_error: 0.0998 - val_mean_absolute_percentage_error: 16.2975 - val_symmetric_mean_absolute_percentage_error: 18.0729
# Epoch 12/50
# 35/35 - 1s - 40ms/step - loss: 0.0054 - mean_absolute_error: 0.0571 - mean_absolute_percentage_error: 348239.1250 - symmetric_mean_absolute_percentage_error: 20.0306 - val_loss: 0.0095 - val_mean_absolute_error: 0.0827 - val_mean_absolute_percentage_error: 13.3361 - val_symmetric_mean_absolute_percentage_error: 14.6780
# Epoch 13/50
# 35/35 - 1s - 43ms/step - loss: 0.0054 - mean_absolute_error: 0.0577 - mean_absolute_percentage_error: 340201.1562 - symmetric_mean_absolute_percentage_error: 20.4033 - val_loss: 0.0154 - val_mean_absolute_error: 0.1084 - val_mean_absolute_percentage_error: 17.5099 - val_symmetric_mean_absolute_percentage_error: 19.9528
# Epoch 14/50
# 35/35 - 2s - 43ms/step - loss: 0.0050 - mean_absolute_error: 0.0547 - mean_absolute_percentage_error: 336337.2500 - symmetric_mean_absolute_percentage_error: 19.5483 - val_loss: 0.0084 - val_mean_absolute_error: 0.0767 - val_mean_absolute_percentage_error: 12.3076 - val_symmetric_mean_absolute_percentage_error: 13.6681
# Epoch 15/50
# 35/35 - 1s - 40ms/step - loss: 0.0053 - mean_absolute_error: 0.0561 - mean_absolute_percentage_error: 334159.9688 - symmetric_mean_absolute_percentage_error: 19.9905 - val_loss: 0.0120 - val_mean_absolute_error: 0.0930 - val_mean_absolute_percentage_error: 14.7934 - val_symmetric_mean_absolute_percentage_error: 16.7963
# Epoch 16/50
# 35/35 - 1s - 37ms/step - loss: 0.0050 - mean_absolute_error: 0.0553 - mean_absolute_percentage_error: 324370.8438 - symmetric_mean_absolute_percentage_error: 19.6562 - val_loss: 0.0137 - val_mean_absolute_error: 0.1004 - val_mean_absolute_percentage_error: 16.0573 - val_symmetric_mean_absolute_percentage_error: 18.3270
# Epoch 17/50
# 35/35 - 1s - 36ms/step - loss: 0.0054 - mean_absolute_error: 0.0571 - mean_absolute_percentage_error: 339004.0312 - symmetric_mean_absolute_percentage_error: 20.1810 - val_loss: 0.0112 - val_mean_absolute_error: 0.0903 - val_mean_absolute_percentage_error: 14.4717 - val_symmetric_mean_absolute_percentage_error: 16.5198
# Epoch 18/50
# 35/35 - 1s - 37ms/step - loss: 0.0046 - mean_absolute_error: 0.0534 - mean_absolute_percentage_error: 331666.1875 - symmetric_mean_absolute_percentage_error: 19.2326 - val_loss: 0.0088 - val_mean_absolute_error: 0.0774 - val_mean_absolute_percentage_error: 12.2849 - val_symmetric_mean_absolute_percentage_error: 13.7745
# Epoch 19/50
# 35/35 - 1s - 38ms/step - loss: 0.0050 - mean_absolute_error: 0.0553 - mean_absolute_percentage_error: 327887.2188 - symmetric_mean_absolute_percentage_error: 19.5203 - val_loss: 0.0053 - val_mean_absolute_error: 0.0554 - val_mean_absolute_percentage_error: 8.8368 - val_symmetric_mean_absolute_percentage_error: 9.7731
# Epoch 20/50
# 35/35 - 1s - 39ms/step - loss: 0.0048 - mean_absolute_error: 0.0550 - mean_absolute_percentage_error: 330904.2188 - symmetric_mean_absolute_percentage_error: 19.7359 - val_loss: 0.0089 - val_mean_absolute_error: 0.0782 - val_mean_absolute_percentage_error: 12.4335 - val_symmetric_mean_absolute_percentage_error: 13.8941
# Epoch 21/50
# 35/35 - 1s - 39ms/step - loss: 0.0048 - mean_absolute_error: 0.0547 - mean_absolute_percentage_error: 321808.6562 - symmetric_mean_absolute_percentage_error: 19.4892 - val_loss: 0.0095 - val_mean_absolute_error: 0.0799 - val_mean_absolute_percentage_error: 12.5838 - val_symmetric_mean_absolute_percentage_error: 14.3226
# Epoch 22/50
# 35/35 - 1s - 41ms/step - loss: 0.0047 - mean_absolute_error: 0.0535 - mean_absolute_percentage_error: 321644.0312 - symmetric_mean_absolute_percentage_error: 19.1476 - val_loss: 0.0129 - val_mean_absolute_error: 0.0965 - val_mean_absolute_percentage_error: 15.3284 - val_symmetric_mean_absolute_percentage_error: 17.5947
# Epoch 23/50
# 35/35 - 1s - 42ms/step - loss: 0.0047 - mean_absolute_error: 0.0530 - mean_absolute_percentage_error: 334021.1562 - symmetric_mean_absolute_percentage_error: 19.1207 - val_loss: 0.0070 - val_mean_absolute_error: 0.0649 - val_mean_absolute_percentage_error: 10.0921 - val_symmetric_mean_absolute_percentage_error: 11.7822
# Epoch 24/50
# 35/35 - 1s - 41ms/step - loss: 0.0051 - mean_absolute_error: 0.0559 - mean_absolute_percentage_error: 338295.4688 - symmetric_mean_absolute_percentage_error: 19.5874 - val_loss: 0.0090 - val_mean_absolute_error: 0.0789 - val_mean_absolute_percentage_error: 12.5893 - val_symmetric_mean_absolute_percentage_error: 14.1949
# Epoch 25/50
# 35/35 - 1s - 40ms/step - loss: 0.0048 - mean_absolute_error: 0.0547 - mean_absolute_percentage_error: 326798.6562 - symmetric_mean_absolute_percentage_error: 19.3817 - val_loss: 0.0065 - val_mean_absolute_error: 0.0628 - val_mean_absolute_percentage_error: 9.8240 - val_symmetric_mean_absolute_percentage_error: 11.0783
# Epoch 26/50
# 35/35 - 1s - 42ms/step - loss: 0.0050 - mean_absolute_error: 0.0552 - mean_absolute_percentage_error: 336578.6875 - symmetric_mean_absolute_percentage_error: 19.5235 - val_loss: 0.0124 - val_mean_absolute_error: 0.0973 - val_mean_absolute_percentage_error: 15.8278 - val_symmetric_mean_absolute_percentage_error: 18.2238
# Epoch 27/50
# 35/35 - 1s - 40ms/step - loss: 0.0045 - mean_absolute_error: 0.0517 - mean_absolute_percentage_error: 318900.2188 - symmetric_mean_absolute_percentage_error: 18.6767 - val_loss: 0.0126 - val_mean_absolute_error: 0.0940 - val_mean_absolute_percentage_error: 14.8216 - val_symmetric_mean_absolute_percentage_error: 17.1674
# Epoch 28/50
# 35/35 - 1s - 38ms/step - loss: 0.0046 - mean_absolute_error: 0.0533 - mean_absolute_percentage_error: 325159.4688 - symmetric_mean_absolute_percentage_error: 19.0509 - val_loss: 0.0090 - val_mean_absolute_error: 0.0750 - val_mean_absolute_percentage_error: 11.6355 - val_symmetric_mean_absolute_percentage_error: 13.4507
# Epoch 29/50
# 35/35 - 2s - 49ms/step - loss: 0.0046 - mean_absolute_error: 0.0540 - mean_absolute_percentage_error: 325069.5312 - symmetric_mean_absolute_percentage_error: 19.2091 - val_loss: 0.0102 - val_mean_absolute_error: 0.0829 - val_mean_absolute_percentage_error: 13.0099 - val_symmetric_mean_absolute_percentage_error: 15.0435
# Epoch 30/50
# 35/35 - 2s - 45ms/step - loss: 0.0044 - mean_absolute_error: 0.0509 - mean_absolute_percentage_error: 339280.5938 - symmetric_mean_absolute_percentage_error: 18.4095 - val_loss: 0.0122 - val_mean_absolute_error: 0.0920 - val_mean_absolute_percentage_error: 14.4609 - val_symmetric_mean_absolute_percentage_error: 17.0273
# Epoch 31/50
# 35/35 - 1s - 41ms/step - loss: 0.0044 - mean_absolute_error: 0.0525 - mean_absolute_percentage_error: 329642.1875 - symmetric_mean_absolute_percentage_error: 18.8589 - val_loss: 0.0077 - val_mean_absolute_error: 0.0694 - val_mean_absolute_percentage_error: 10.7946 - val_symmetric_mean_absolute_percentage_error: 12.3127
# Epoch 32/50
# 35/35 - 1s - 43ms/step - loss: 0.0044 - mean_absolute_error: 0.0518 - mean_absolute_percentage_error: 341158.8125 - symmetric_mean_absolute_percentage_error: 18.8164 - val_loss: 0.0148 - val_mean_absolute_error: 0.1065 - val_mean_absolute_percentage_error: 17.1766 - val_symmetric_mean_absolute_percentage_error: 20.0854
# Epoch 33/50
# 35/35 - 2s - 46ms/step - loss: 0.0047 - mean_absolute_error: 0.0535 - mean_absolute_percentage_error: 317655.1250 - symmetric_mean_absolute_percentage_error: 18.8245 - val_loss: 0.0091 - val_mean_absolute_error: 0.0777 - val_mean_absolute_percentage_error: 12.1823 - val_symmetric_mean_absolute_percentage_error: 13.9435
# Epoch 34/50
# 35/35 - 1s - 42ms/step - loss: 0.0041 - mean_absolute_error: 0.0499 - mean_absolute_percentage_error: 321601.5000 - symmetric_mean_absolute_percentage_error: 18.1858 - val_loss: 0.0119 - val_mean_absolute_error: 0.0933 - val_mean_absolute_percentage_error: 14.9182 - val_symmetric_mean_absolute_percentage_error: 17.3227
# Model saved to outputs/stock_price_lstm_apple_model.keras
# Model loaded from outputs/stock_price_lstm_apple_model.keras
# Scaler loaded from outputs/apple_scale.pkl
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 191ms/step
# Predictions (rescaled): [[202.6565 ]
#  [203.34567]
#  [204.12248]
#  [204.82594]
#  [205.68445]
#  [206.53331]
#  [207.24535]
#  [206.96173]
#  [207.76181]
#  [208.88626]
#  [209.05034]
#  [205.7904 ]
#  [202.67789]
#  [202.4997 ]
#  [203.37305]
#  [204.80017]
#  [202.7841 ]
#  [201.74713]
#  [202.01752]
#  [202.72505]
#  [203.48016]
#  [205.13194]
#  [204.00711]
#  [203.93253]
#  [199.67943]
#  [197.48895]
#  [198.3915 ]
#  [201.00456]
#  [202.33131]
#  [203.34302]
#  [204.19348]
#  [205.09404]
#  [205.84865]
#  [206.63567]
#  [206.91998]
#  [206.81627]
#  [206.34782]
#  [205.18196]
#  [205.78055]
#  [206.21625]
#  [206.61429]
#  [205.8526 ]
#  [206.825  ]
#  [206.61841]
#  [203.6926 ]
#  [202.11966]
#  [202.95364]
#  [203.30466]
#  [203.79277]
#  [203.75461]
#  [204.81485]
#  [205.17177]
#  [204.96733]
#  [202.2083 ]
#  [201.55756]
#  [203.49107]
#  [205.53036]
#  [206.66933]
#  [206.89476]
#  [206.76889]
#  [205.85713]
#  [205.84654]
#  [205.94392]
#  [208.1634 ]
#  [205.5807 ]
#  [204.70546]
#  [204.20746]
#  [204.93214]
#  [203.31522]
#  [204.73976]
#  [207.08572]
#  [207.30951]
#  [206.08781]
#  [206.90002]
#  [208.01129]
#  [206.95047]
#  [206.34294]
#  [207.25737]
#  [207.96039]
#  [207.37328]
#  [204.56224]
#  [203.85194]
#  [204.72363]
#  [206.38109]]
# 3/3 - 1s - 356ms/step - loss: 0.0347 - mean_absolute_error: 0.1816 - mean_absolute_percentage_error: 20.0167 - symmetric_mean_absolute_percentage_error: 22.8241
# loss: 0.0347
# compile_metrics: 0.1816
# SMAPE (manual, rescaled): 9.3804
