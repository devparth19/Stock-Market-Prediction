# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, SimpleRNN, Dropout
from sklearn.preprocessing import MinMaxScaler
import joblib  # For saving the scaler
import os
import pandas as pd
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
import tensorflow.lite as tflite
import random
import os
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import pickle





SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
os.environ['TF_DETERMINISTIC_OPS'] = '1'
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'


# In[11]:


def preprocess_stock_data(
    csv_path, 
    date_column='Date', 
    close_column='Close', 
    test_size=0.2, 
    validation_size=0.1,
    time_steps=60, 
    scaler_output_file='outputs/meta_scale.pkl'
):
    """
    Prepares stock market price data for time series modeling, with training, validation, and test splits.

    Args:
        csv_path (str): Path to the CSV file containing the data.
        date_column (str): Name of the date column in the CSV.
        close_column (str): Name of the closing price column in the CSV.
        test_size (float): Proportion of the data for testing.
        validation_size (float): Proportion of the data for validation.
        time_steps (int): Number of past time steps to use for each sample.
        scaler_output_file (str): Path to save the fitted MinMaxScaler instance.

    Returns:
        X_train (numpy.ndarray): Training data (features).
        y_train (numpy.ndarray): Training labels.
        X_val (numpy.ndarray): Validation data (features).
        y_val (numpy.ndarray): Validation labels.
        X_test (numpy.ndarray): Testing data (features).
        y_test (numpy.ndarray): Testing labels.
    """
    try:
        # Load the dataset
        if not os.path.exists(csv_path):
            raise FileNotFoundError(f"CSV file not found at path: {csv_path}")

        data = pd.read_csv(csv_path, parse_dates=[date_column])
        data.sort_values(by=date_column, inplace=True)

        print(f"CSV file successfully loaded. Columns: {data.columns}")
    except Exception as e:
        raise ValueError(f"Error reading CSV file or parsing date column '{date_column}': {e}")
    
    # Validate columns
    if date_column not in data.columns or close_column not in data.columns:
        raise ValueError(f"Columns '{date_column}' or '{close_column}' not found in dataset. Available columns: {data.columns}")

    try:
        # Extract the 'close' column for scaling
        close_prices = data[close_column].values.reshape(-1, 1)
    except Exception as e:
        raise ValueError(f"Error accessing '{close_column}' column: {e}")
    
    # Scale the data
    try:
        scaler = MinMaxScaler(feature_range=(0, 1))
        scaled_close = scaler.fit_transform(close_prices)

        # Save the scaler to a file
        with open(scaler_output_file, 'wb') as f:
            pickle.dump(scaler, f)
        print(f"Scaler saved to {scaler_output_file}")
    except Exception as e:
        raise IOError(f"Error during scaling or saving scaler: {e}")
    
    # Create sequences of time_steps
    X, y = [], []
    try:
        for i in range(time_steps, len(scaled_close)):
            X.append(scaled_close[i - time_steps:i])
            y.append(scaled_close[i])
    except Exception as e:
        raise ValueError(f"Error creating sequences of time_steps: {e}")
    
    X, y = np.array(X), np.array(y)
    
    # Split data into train, validation, and test sets
    try:
        total_size = len(X)
        test_size_count = int(test_size * total_size)
        validation_size_count = int(validation_size * total_size)

        train_end_idx = total_size - test_size_count - validation_size_count
        val_end_idx = total_size - test_size_count

        X_train, X_val, X_test = X[:train_end_idx], X[train_end_idx:val_end_idx], X[val_end_idx:]
        y_train, y_val, y_test = y[:train_end_idx], y[train_end_idx:val_end_idx], y[val_end_idx:]

        # Adjust splits to match desired sample sizes
        train_samples = 554
        val_samples = 55
        test_samples = 84

        X_train, y_train = X[:train_samples], y[:train_samples]
        X_val, y_val = X[train_samples:train_samples + val_samples], y[train_samples:train_samples + val_samples]
        X_test, y_test = X[train_samples + val_samples:train_samples + val_samples + test_samples], y[train_samples + val_samples:train_samples + val_samples + test_samples]
    except Exception as e:
        raise ValueError(f"Error splitting data into train, validation, and test sets: {e}")
    
    print(f"Data split: {len(X_train)} training samples, {len(X_val)} validation samples, {len(X_test)} testing samples")
    
    return X_train, y_train, X_val, y_val, X_test, y_test





data = "inputs/meta_stock_cleaned.csv"


try:
    X_train, y_train, X_val, y_val, X_test, y_test = preprocess_stock_data(
        data, 
        date_column='Date', 
        close_column='Close', 
        test_size=0.2, 
        time_steps=60, 
        scaler_output_file='outputs/meta_scale.pkl'
    )

    # Outputs
    print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
    print(f"X_train shape: {X_val.shape}, y_train shape: {y_val.shape}")
    print(f"X_test shape: {X_test.shape}, y_test shape: {y_test.shape}")
except ValueError as ve:
    print(f"ValueError: {ve}")
except Exception as e:
    print(f"Unexpected Error: {e}")





print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)




from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import SimpleRNN, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
import tensorflow as tf
import joblib
import numpy as np
import os

@tf.keras.utils.register_keras_serializable(package="Custom", name="symmetric_mean_absolute_percentage_error")
def symmetric_mean_absolute_percentage_error(y_true, y_pred):
    """
    Computes Symmetric Mean Absolute Percentage Error (SMAPE).

    Args:
        y_true: Ground truth values.
        y_pred: Predicted values.

    Returns:
        SMAPE as a TensorFlow tensor.
    """
    numerator = tf.abs(y_true - y_pred)
    denominator = (tf.abs(y_true) + tf.abs(y_pred)) / 2
    smape = tf.reduce_mean(numerator / denominator) * 100
    return smape


class StockPricePredictor_Meta:
    def __init__(self, input_shape, learning_rate=0.04624064196479419, num_layers=2, units=32):
        self.input_shape = input_shape  # Should be (time_steps, features)
        self.learning_rate = learning_rate
        self.num_layers = num_layers
        self.units = units
        self.model = self._build_model()

    def _build_model(self):
        model = Sequential()
        for i in range(self.num_layers):
            # Add RNN layers
            return_sequences = i < (self.num_layers - 1)
            model.add(SimpleRNN(self.units, activation='relu', return_sequences=return_sequences, input_shape=self.input_shape))
            model.add(Dropout(0.2))  # Regularization

        # Output layer for regression (single output: close value)
        model.add(Dense(1))

        # Compile the model
        model.compile(
            optimizer=tf.keras.optimizers.Adam(learning_rate=self.learning_rate),
            loss=tf.keras.losses.MeanSquaredError(),
            metrics=[
                tf.keras.metrics.MeanAbsoluteError(),
                tf.keras.metrics.MeanAbsolutePercentageError(),
                symmetric_mean_absolute_percentage_error  # Custom SMAPE metric
            ]
        )
        return model

    def train(self, X_train, y_train, batch_size=16, epochs=50, validation_data=None, patience=15):
        """
        Trains the model with an EarlyStopping callback.
        
        Args:
            X_train: Training input data.
            y_train: Training target data.
            batch_size: Batch size for training.
            epochs: Maximum number of training epochs.
            validation_data: Tuple (X_val, y_val) for validation.
            patience: Number of epochs with no improvement after which training will be stopped.
        
        Returns:
            History object containing training details.
        """
        X_train = self._validate_and_reshape(X_train, expected_shape=(None, *self.input_shape))
        if validation_data:
            X_val = self._validate_and_reshape(validation_data[0], expected_shape=(None, *self.input_shape))
            validation_data = (X_val, validation_data[1])

        early_stopping = EarlyStopping(
            monitor='val_loss',
            patience=patience,
            restore_best_weights=True
        )

        history = self.model.fit(
            X_train, y_train,
            batch_size=batch_size,
            epochs=epochs,
            validation_data=validation_data,
            callbacks=[early_stopping],
            verbose=2
        )
        return history

    def predict(self, X):
        X = self._validate_and_reshape(X, expected_shape=(None, *self.input_shape))
        return self.model.predict(X)

    def save(self, model_path):
        self.model.save(model_path)
        print(f"Model saved to {model_path}")

    @staticmethod
    def load(model_path, scaler_path):
        model = load_model(model_path, custom_objects={
            "symmetric_mean_absolute_percentage_error": symmetric_mean_absolute_percentage_error
        })
        print(f"Model loaded from {model_path}")

        scaler = joblib.load(scaler_path)
        print(f"Scaler loaded from {scaler_path}")

        return model, scaler

    def _validate_and_reshape(self, X, expected_shape):
        if len(X.shape) == 2:
            reshaped = X[..., np.newaxis]
            print(f"Reshaped input from {X.shape} to {reshaped.shape}")
            return reshaped
        elif len(X.shape) == len(expected_shape):
            print(f"Input shape is valid: {X.shape}")
            return X
        else:
            raise ValueError(f"Invalid input shape {X.shape}. Expected shape {expected_shape}.")





data_path_meta = "inputs/meta_stock_cleaned.csv"




if __name__ == "__main__":
    # Example input data
    input_shape = (60, 1)  # 60 time steps, 1 feature (e.g., close price)
    predictor = StockPricePredictor_Meta(input_shape=input_shape)

    # Training
    predictor.train(X_train, y_train, validation_data=(X_val, y_val))

    # Save the model
    model_path = "outputs/stock_price_rnn_meta_model.keras"
    scaler_path = "outputs/meta_scale.pkl"
    predictor.save(model_path)

    # Load model and scaler for inference
    loaded_model, loaded_scaler = StockPricePredictor_Meta.load(model_path, scaler_path)

    # Predict on test data
    predictions = loaded_model.predict(X_test)
    predictions_rescaled = loaded_scaler.inverse_transform(predictions).astype('float32')

    # Rescale test labels for evaluation (if scaled)
    y_test_rescaled = loaded_scaler.inverse_transform(y_test.reshape(-1, 1)).astype('float32')

    # Print predictions
    print("Predictions (rescaled):", predictions_rescaled.astype('float32'))

    # Evaluate metrics on test data
    metrics = loaded_model.evaluate(X_test, y_test, verbose=2)
    metric_names = loaded_model.metrics_names  # Get metric names for better interpretability

    # Display metrics
    for name, value in zip(metric_names, metrics):
        print(f"{name}: {value:.4f}")

    # Compute and display custom SMAPE manually for rescaled predictions
    smape_manual = symmetric_mean_absolute_percentage_error(y_test_rescaled, predictions_rescaled)
    print(f"SMAPE (manual, rescaled): {smape_manual.numpy():.4f}")




plt.figure(figsize=(12, 6))
plt.plot(loaded_scaler.inverse_transform(y_test.reshape(-1, 1)), label="Actual Prices", color="darkorange", alpha=0.6, linewidth=2)
plt.plot(loaded_scaler.inverse_transform(predictions.reshape(-1, 1)), label="Predicted Prices", color="#4267B2", alpha=0.6, linestyle="--", linewidth=2)
plt.title("Stock Price Prediction for Meta",fontsize = 26)
plt.xlabel("Time Steps",fontsize = 20)
plt.ylabel("Stock Price (Original Scale)",fontsize = 20)
plt.legend(fontsize = 20)
plt.grid(True)
plt.savefig('results/meta_result.png', bbox_inches='tight')
plt.show()
# Out:
# CSV file successfully loaded. Columns: Index(['Unnamed: 0', 'Date', 'Open', 'High', 'Low', 'Close', 'Adj Close',
#        'Volume', 'daily_return', '20_day_ma', '50_day_ma'],
#       dtype='object')
# Scaler saved to outputs/meta_scale.pkl
# Data split: 554 training samples, 55 validation samples, 84 testing samples
# X_train shape: (554, 60, 1), y_train shape: (554, 1)
# X_train shape: (55, 60, 1), y_train shape: (55, 1)
# X_test shape: (84, 60, 1), y_test shape: (84, 1)
# X_train shape: (554, 60, 1)
# y_train shape: (554, 1)
# Input shape is valid: (554, 60, 1)
# Input shape is valid: (55, 60, 1)
# Epoch 1/50
# C:\Users\parth\mp_env\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 35/35 - 4s - 124ms/step - loss: 0.2129 - mean_absolute_error: 0.2195 - mean_absolute_percentage_error: 5551.7490 - symmetric_mean_absolute_percentage_error: 72.3815 - val_loss: 0.0828 - val_mean_absolute_error: 0.2860 - val_mean_absolute_percentage_error: 36.7651 - val_symmetric_mean_absolute_percentage_error: 45.5037
# Epoch 2/50
# 35/35 - 1s - 25ms/step - loss: 0.0179 - mean_absolute_error: 0.1009 - mean_absolute_percentage_error: 205534.0938 - symmetric_mean_absolute_percentage_error: 41.0331 - val_loss: 0.0784 - val_mean_absolute_error: 0.2788 - val_mean_absolute_percentage_error: 35.8850 - val_symmetric_mean_absolute_percentage_error: 43.9271
# Epoch 3/50
# 35/35 - 1s - 22ms/step - loss: 0.0146 - mean_absolute_error: 0.0882 - mean_absolute_percentage_error: 144891.3125 - symmetric_mean_absolute_percentage_error: 33.9310 - val_loss: 0.0406 - val_mean_absolute_error: 0.2003 - val_mean_absolute_percentage_error: 25.7879 - val_symmetric_mean_absolute_percentage_error: 29.6923
# Epoch 4/50
# 35/35 - 1s - 24ms/step - loss: 0.0130 - mean_absolute_error: 0.0895 - mean_absolute_percentage_error: 311507.7812 - symmetric_mean_absolute_percentage_error: 36.3899 - val_loss: 0.0079 - val_mean_absolute_error: 0.0828 - val_mean_absolute_percentage_error: 10.5562 - val_symmetric_mean_absolute_percentage_error: 11.5840
# Epoch 5/50
# 35/35 - 1s - 22ms/step - loss: 0.0115 - mean_absolute_error: 0.0773 - mean_absolute_percentage_error: 321894.1875 - symmetric_mean_absolute_percentage_error: 31.6790 - val_loss: 6.1539e-04 - val_mean_absolute_error: 0.0175 - val_mean_absolute_percentage_error: 2.2901 - val_symmetric_mean_absolute_percentage_error: 2.2252
# Epoch 6/50
# 35/35 - 1s - 25ms/step - loss: 0.0081 - mean_absolute_error: 0.0656 - mean_absolute_percentage_error: 184513.8281 - symmetric_mean_absolute_percentage_error: 28.0985 - val_loss: 0.0321 - val_mean_absolute_error: 0.1771 - val_mean_absolute_percentage_error: 22.7439 - val_symmetric_mean_absolute_percentage_error: 25.9128
# Epoch 7/50
# 35/35 - 1s - 26ms/step - loss: 0.0101 - mean_absolute_error: 0.0695 - mean_absolute_percentage_error: 178006.7656 - symmetric_mean_absolute_percentage_error: 28.3034 - val_loss: 0.0382 - val_mean_absolute_error: 0.1934 - val_mean_absolute_percentage_error: 24.8762 - val_symmetric_mean_absolute_percentage_error: 28.5494
# Epoch 8/50
# 35/35 - 1s - 21ms/step - loss: 0.0111 - mean_absolute_error: 0.0781 - mean_absolute_percentage_error: 312569.7188 - symmetric_mean_absolute_percentage_error: 31.7240 - val_loss: 0.0333 - val_mean_absolute_error: 0.1801 - val_mean_absolute_percentage_error: 23.1200 - val_symmetric_mean_absolute_percentage_error: 26.5069
# Epoch 9/50
# 35/35 - 1s - 24ms/step - loss: 0.0100 - mean_absolute_error: 0.0749 - mean_absolute_percentage_error: 304743.5000 - symmetric_mean_absolute_percentage_error: 31.6768 - val_loss: 0.0398 - val_mean_absolute_error: 0.1976 - val_mean_absolute_percentage_error: 25.4286 - val_symmetric_mean_absolute_percentage_error: 29.1922
# Epoch 10/50
# 35/35 - 1s - 20ms/step - loss: 0.0106 - mean_absolute_error: 0.0743 - mean_absolute_percentage_error: 252688.0938 - symmetric_mean_absolute_percentage_error: 29.5813 - val_loss: 0.0079 - val_mean_absolute_error: 0.0855 - val_mean_absolute_percentage_error: 10.9853 - val_symmetric_mean_absolute_percentage_error: 11.7259
# Epoch 11/50
# 35/35 - 1s - 24ms/step - loss: 0.0070 - mean_absolute_error: 0.0601 - mean_absolute_percentage_error: 255029.6562 - symmetric_mean_absolute_percentage_error: 26.1354 - val_loss: 0.0014 - val_mean_absolute_error: 0.0298 - val_mean_absolute_percentage_error: 3.9076 - val_symmetric_mean_absolute_percentage_error: 3.7824
# Epoch 12/50
# 35/35 - 1s - 26ms/step - loss: 0.0095 - mean_absolute_error: 0.0660 - mean_absolute_percentage_error: 279523.5000 - symmetric_mean_absolute_percentage_error: 27.5796 - val_loss: 0.0019 - val_mean_absolute_error: 0.0368 - val_mean_absolute_percentage_error: 4.8160 - val_symmetric_mean_absolute_percentage_error: 4.7863
# Epoch 13/50
# 35/35 - 1s - 22ms/step - loss: 0.0073 - mean_absolute_error: 0.0614 - mean_absolute_percentage_error: 272046.2812 - symmetric_mean_absolute_percentage_error: 26.5211 - val_loss: 0.0021 - val_mean_absolute_error: 0.0405 - val_mean_absolute_percentage_error: 5.2552 - val_symmetric_mean_absolute_percentage_error: 5.2334
# Epoch 14/50
# 35/35 - 1s - 25ms/step - loss: 0.0071 - mean_absolute_error: 0.0620 - mean_absolute_percentage_error: 269865.2812 - symmetric_mean_absolute_percentage_error: 26.5977 - val_loss: 0.0050 - val_mean_absolute_error: 0.0675 - val_mean_absolute_percentage_error: 8.6713 - val_symmetric_mean_absolute_percentage_error: 9.1158
# Epoch 15/50
# 35/35 - 1s - 24ms/step - loss: 0.0083 - mean_absolute_error: 0.0672 - mean_absolute_percentage_error: 251745.2656 - symmetric_mean_absolute_percentage_error: 28.6486 - val_loss: 0.0333 - val_mean_absolute_error: 0.1794 - val_mean_absolute_percentage_error: 22.9610 - val_symmetric_mean_absolute_percentage_error: 26.5701
# Epoch 16/50
# 35/35 - 1s - 25ms/step - loss: 0.0088 - mean_absolute_error: 0.0724 - mean_absolute_percentage_error: 171032.6719 - symmetric_mean_absolute_percentage_error: 30.8582 - val_loss: 0.0012 - val_mean_absolute_error: 0.0282 - val_mean_absolute_percentage_error: 3.5626 - val_symmetric_mean_absolute_percentage_error: 3.9810
# Epoch 17/50
# 35/35 - 1s - 25ms/step - loss: 0.0104 - mean_absolute_error: 0.0779 - mean_absolute_percentage_error: 280733.4688 - symmetric_mean_absolute_percentage_error: 32.2225 - val_loss: 0.0040 - val_mean_absolute_error: 0.0605 - val_mean_absolute_percentage_error: 7.7204 - val_symmetric_mean_absolute_percentage_error: 8.3562
# Epoch 18/50
# 35/35 - 1s - 22ms/step - loss: 0.0100 - mean_absolute_error: 0.0730 - mean_absolute_percentage_error: 316214.6875 - symmetric_mean_absolute_percentage_error: 30.6241 - val_loss: 0.0011 - val_mean_absolute_error: 0.0277 - val_mean_absolute_percentage_error: 3.5242 - val_symmetric_mean_absolute_percentage_error: 3.8871
# Epoch 19/50
# 35/35 - 1s - 23ms/step - loss: 0.0079 - mean_absolute_error: 0.0668 - mean_absolute_percentage_error: 155490.6250 - symmetric_mean_absolute_percentage_error: 28.7221 - val_loss: 0.0081 - val_mean_absolute_error: 0.0870 - val_mean_absolute_percentage_error: 11.1962 - val_symmetric_mean_absolute_percentage_error: 11.9210
# Epoch 20/50
# 35/35 - 1s - 20ms/step - loss: 10838.3252 - mean_absolute_error: 12.5762 - mean_absolute_percentage_error: 302499.7500 - symmetric_mean_absolute_percentage_error: 45.1014 - val_loss: 0.1095 - val_mean_absolute_error: 0.3296 - val_mean_absolute_percentage_error: 42.8552 - val_symmetric_mean_absolute_percentage_error: 34.5791
# Model saved to outputs/stock_price_rnn_meta_model.keras
# Model loaded from outputs/stock_price_rnn_meta_model.keras
# Scaler loaded from outputs/meta_scale.pkl
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 153ms/step
# Predictions (rescaled): [[501.34573]
#  [493.47614]
#  [505.44507]
#  [516.90283]
#  [521.6516 ]
#  [520.24396]
#  [512.8577 ]
#  [516.4615 ]
#  [498.88892]
#  [486.92706]
#  [491.31848]
#  [473.5902 ]
#  [477.2514 ]
#  [477.92752]
#  [476.91998]
#  [485.57364]
#  [466.23053]
#  [461.04092]
#  [458.20947]
#  [460.46902]
#  [463.0009 ]
#  [464.73047]
#  [483.5943 ]
#  [487.0366 ]
#  [473.79358]
#  [481.4694 ]
#  [481.19955]
#  [491.16232]
#  [505.7404 ]
#  [502.71338]
#  [508.44543]
#  [512.4187 ]
#  [513.87225]
#  [514.6439 ]
#  [514.5253 ]
#  [509.532  ]
#  [524.20276]
#  [516.1827 ]
#  [515.04706]
#  [511.75433]
#  [510.3449 ]
#  [509.45175]
#  [507.72037]
#  [503.09106]
#  [510.38657]
#  [500.13144]
#  [502.86203]
#  [502.4682 ]
#  [498.52728]
#  [501.1369 ]
#  [501.27484]
#  [504.3779 ]
#  [518.26135]
#  [514.2779 ]
#  [513.0356 ]
#  [525.19604]
#  [526.8861 ]
#  [544.31604]
#  [541.4431 ]
#  [535.7733 ]
#  [554.3813 ]
#  [540.58356]
#  [539.6837 ]
#  [552.9671 ]
#  [548.92444]
#  [556.5509 ]
#  [558.78864]
#  [559.91046]
#  [569.29047]
#  [564.75336]
#  [561.68835]
#  [567.98956]
#  [567.3549 ]
#  [568.2969 ]
#  [572.5757 ]
#  [561.83154]
#  [556.9152 ]
#  [566.907  ]
#  [556.53766]
#  [568.27686]
#  [555.929  ]
#  [547.71295]
#  [562.7526 ]
#  [558.6088 ]]
# 3/3 - 1s - 289ms/step - loss: 0.0014 - mean_absolute_error: 0.0324 - mean_absolute_percentage_error: 3.6458 - symmetric_mean_absolute_percentage_error: 3.7862
# loss: 0.0014
# compile_metrics: 0.0324
# SMAPE (manual, rescaled): 3.0935
