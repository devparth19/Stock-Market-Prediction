# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, SimpleRNN, Dropout
from sklearn.preprocessing import MinMaxScaler
import joblib  # For saving the scaler
import os
import pandas as pd
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
import tensorflow.lite as tflite
import random
import os
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import pickle





SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
os.environ['TF_DETERMINISTIC_OPS'] = '1'
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'




def preprocess_stock_data(
    csv_path, 
    date_column='Date', 
    close_column='Close', 
    test_size=0.2, 
    validation_size=0.1,
    time_steps=60, 
    scaler_output_file='outputs/nvidia_scale.pkl'
):
    """
    Prepares stock market price data for time series modeling, with training, validation, and test splits.

    Args:
        csv_path (str): Path to the CSV file containing the data.
        date_column (str): Name of the date column in the CSV.
        close_column (str): Name of the closing price column in the CSV.
        test_size (float): Proportion of the data for testing.
        validation_size (float): Proportion of the data for validation.
        time_steps (int): Number of past time steps to use for each sample.
        scaler_output_file (str): Path to save the fitted MinMaxScaler instance.

    Returns:
        X_train (numpy.ndarray): Training data (features).
        y_train (numpy.ndarray): Training labels.
        X_val (numpy.ndarray): Validation data (features).
        y_val (numpy.ndarray): Validation labels.
        X_test (numpy.ndarray): Testing data (features).
        y_test (numpy.ndarray): Testing labels.
    """
    try:
        # Load the dataset
        if not os.path.exists(csv_path):
            raise FileNotFoundError(f"CSV file not found at path: {csv_path}")

        data = pd.read_csv(csv_path, parse_dates=[date_column])
        data.sort_values(by=date_column, inplace=True)

        print(f"CSV file successfully loaded. Columns: {data.columns}")
    except Exception as e:
        raise ValueError(f"Error reading CSV file or parsing date column '{date_column}': {e}")
    
    # Validate columns
    if date_column not in data.columns or close_column not in data.columns:
        raise ValueError(f"Columns '{date_column}' or '{close_column}' not found in dataset. Available columns: {data.columns}")

    try:
        # Extract the 'close' column for scaling
        close_prices = data[close_column].values.reshape(-1, 1)
    except Exception as e:
        raise ValueError(f"Error accessing '{close_column}' column: {e}")
    
    # Scale the data
    try:
        scaler = MinMaxScaler(feature_range=(0, 1))
        scaled_close = scaler.fit_transform(close_prices)

        # Save the scaler to a file
        with open(scaler_output_file, 'wb') as f:
            pickle.dump(scaler, f)
        print(f"Scaler saved to {scaler_output_file}")
    except Exception as e:
        raise IOError(f"Error during scaling or saving scaler: {e}")
    
    # Create sequences of time_steps
    X, y = [], []
    try:
        for i in range(time_steps, len(scaled_close)):
            X.append(scaled_close[i - time_steps:i])
            y.append(scaled_close[i])
    except Exception as e:
        raise ValueError(f"Error creating sequences of time_steps: {e}")
    
    X, y = np.array(X), np.array(y)
    
    # Split data into train, validation, and test sets
    try:
        total_size = len(X)
        test_size_count = int(test_size * total_size)
        validation_size_count = int(validation_size * total_size)

        train_end_idx = total_size - test_size_count - validation_size_count
        val_end_idx = total_size - test_size_count

        X_train, X_val, X_test = X[:train_end_idx], X[train_end_idx:val_end_idx], X[val_end_idx:]
        y_train, y_val, y_test = y[:train_end_idx], y[train_end_idx:val_end_idx], y[val_end_idx:]

        # Adjust splits to match desired sample sizes
        train_samples = 554
        val_samples = 55
        test_samples = 84

        X_train, y_train = X[:train_samples], y[:train_samples]
        X_val, y_val = X[train_samples:train_samples + val_samples], y[train_samples:train_samples + val_samples]
        X_test, y_test = X[train_samples + val_samples:train_samples + val_samples + test_samples], y[train_samples + val_samples:train_samples + val_samples + test_samples]
    except Exception as e:
        raise ValueError(f"Error splitting data into train, validation, and test sets: {e}")
    
    print(f"Data split: {len(X_train)} training samples, {len(X_val)} validation samples, {len(X_test)} testing samples")
    
    return X_train, y_train, X_val, y_val, X_test, y_test





data = "inputs/nvidia_stock_cleaned.csv"


try:
    X_train, y_train, X_val, y_val, X_test, y_test = preprocess_stock_data(
        data, 
        date_column='Date', 
        close_column='Close', 
        test_size=0.2, 
        time_steps=60, 
        scaler_output_file='outputs/nvidia_scale.pkl'
    )

    # Outputs
    print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
    print(f"X_train shape: {X_val.shape}, y_train shape: {y_val.shape}")
    print(f"X_test shape: {X_test.shape}, y_test shape: {y_test.shape}")
except ValueError as ve:
    print(f"ValueError: {ve}")
except Exception as e:
    print(f"Unexpected Error: {e}")





print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)




from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import SimpleRNN, Dense, Dropout, LSTM, MultiHeadAttention, LayerNormalization
from tensorflow.keras.callbacks import EarlyStopping
import tensorflow as tf
import joblib
import numpy as np
import os

@tf.keras.utils.register_keras_serializable(package="Custom", name="symmetric_mean_absolute_percentage_error")
def symmetric_mean_absolute_percentage_error(y_true, y_pred):
    """
    Computes Symmetric Mean Absolute Percentage Error (SMAPE).

    Args:
        y_true: Ground truth values.
        y_pred: Predicted values.

    Returns:
        SMAPE as a TensorFlow tensor.
    """
    numerator = tf.abs(y_true - y_pred)
    denominator = (tf.abs(y_true) + tf.abs(y_pred)) / 2
    smape = tf.reduce_mean(numerator / denominator) * 100
    return smape


class StockPricePredictor_Nvidia:
    def __init__(self, input_shape, learning_rate=0.016352092151644158, num_layers=1, units=32):
        self.input_shape = input_shape  # Should be (time_steps, features)
        self.learning_rate = learning_rate
        self.num_layers = num_layers
        self.units = units
        self.model = self._build_model()

    def _build_model(self):
        model = Sequential()
        for i in range(self.num_layers):
            # Add LSTM layers
            return_sequences = i < (self.num_layers - 1)
            model.add(LSTM(self.units, activation='relu', return_sequences=return_sequences, input_shape=self.input_shape))
            model.add(Dropout(0.2))  # Regularization

        # Output layer for regression (single output: close value)
        model.add(Dense(1))

        # Compile the model
        model.compile(
            optimizer=tf.keras.optimizers.Adam(learning_rate=self.learning_rate),
            loss=tf.keras.losses.MeanSquaredError(),
            metrics=[
                tf.keras.metrics.MeanAbsoluteError(),
                tf.keras.metrics.MeanAbsolutePercentageError(),
                symmetric_mean_absolute_percentage_error  # Custom SMAPE metric
            ]
        )
        return model

    def train(self, X_train, y_train, batch_size=32, epochs=50, validation_data=None, patience=15):
        """
        Trains the model with an EarlyStopping callback.
        
        Args:
            X_train: Training input data.
            y_train: Training target data.
            batch_size: Batch size for training.
            epochs: Maximum number of training epochs.
            validation_data: Tuple (X_val, y_val) for validation.
            patience: Number of epochs with no improvement after which training will be stopped.
        
        Returns:
            History object containing training details.
        """
        X_train = self._validate_and_reshape(X_train, expected_shape=(None, *self.input_shape))
        if validation_data:
            X_val = self._validate_and_reshape(validation_data[0], expected_shape=(None, *self.input_shape))
            validation_data = (X_val, validation_data[1])

        early_stopping = EarlyStopping(
            monitor='val_loss',
            patience=patience,
            restore_best_weights=True
        )

        history = self.model.fit(
            X_train, y_train,
            batch_size=batch_size,
            epochs=epochs,
            validation_data=validation_data,
            callbacks=[early_stopping],
            verbose=2
        )
        return history

    def predict(self, X):
        X = self._validate_and_reshape(X, expected_shape=(None, *self.input_shape))
        return self.model.predict(X)

    def save(self, model_path):
        self.model.save(model_path)
        print(f"Model saved to {model_path}")

    @staticmethod
    def load(model_path, scaler_path):
        model = load_model(model_path, custom_objects={
            "symmetric_mean_absolute_percentage_error": symmetric_mean_absolute_percentage_error
        })
        print(f"Model loaded from {model_path}")

        scaler = joblib.load(scaler_path)
        print(f"Scaler loaded from {scaler_path}")

        return model, scaler

    def _validate_and_reshape(self, X, expected_shape):
        if len(X.shape) == 2:
            reshaped = X[..., np.newaxis]
            print(f"Reshaped input from {X.shape} to {reshaped.shape}")
            return reshaped
        elif len(X.shape) == len(expected_shape):
            print(f"Input shape is valid: {X.shape}")
            return X
        else:
            raise ValueError(f"Invalid input shape {X.shape}. Expected shape {expected_shape}.")




# In[15]:


data_path_nvidia = "inputs/nvidia_stock_cleaned.csv"



if __name__ == "__main__":
    # Example input data
    input_shape = (60, 1)  # 60 time steps, 1 feature (e.g., close price)
    predictor = StockPricePredictor_Nvidia(input_shape=input_shape)

    # Training
    predictor.train(X_train, y_train, validation_data=(X_val, y_val))

    # Save the model
    model_path = "outputs/stock_price_lstm_nvidia_model.keras"
    scaler_path = "outputs/nvidia_scale.pkl"
    predictor.save(model_path)

    # Load model and scaler for inference
    loaded_model, loaded_scaler = StockPricePredictor_Nvidia.load(model_path, scaler_path)

    # Predict on test data
    predictions = loaded_model.predict(X_test)
    predictions_rescaled = loaded_scaler.inverse_transform(predictions).astype('float32')

    # Rescale test labels for evaluation (if scaled)
    y_test_rescaled = loaded_scaler.inverse_transform(y_test.reshape(-1, 1)).astype('float32')

    # Print predictions
    print("Predictions (rescaled):", predictions_rescaled.astype('float32'))

    # Evaluate metrics on test data
    metrics = loaded_model.evaluate(X_test, y_test , verbose=2)
    metric_names = loaded_model.metrics_names  # Get metric names for better interpretability

    # Display metrics
    for name, value in zip(metric_names, metrics):
        print(f"{name}: {value:.4f}")

    # Compute and display custom SMAPE manually for rescaled predictions
    smape_manual = symmetric_mean_absolute_percentage_error(y_test_rescaled, predictions_rescaled)
    print(f"SMAPE (manual, rescaled): {smape_manual.numpy():.4f}")





plt.figure(figsize=(12, 6))
plt.plot(loaded_scaler.inverse_transform(y_test.reshape(-1, 1)), label="Actual Prices", color="darkorange", alpha=0.6, linewidth=2)
plt.plot(loaded_scaler.inverse_transform(predictions.reshape(-1, 1)), label="Predicted Prices", color="#76B900", alpha=0.6, linestyle="--", linewidth=2)
plt.title("Stock Price Prediction for Nvidia",fontsize = 26)
plt.xlabel("Time Steps",fontsize = 20)
plt.ylabel("Stock Price (Original Scale)",fontsize = 20)
plt.legend(fontsize = 20)
plt.grid(True)
plt.savefig('results/nvidia_result.png', bbox_inches='tight')
plt.show()
# Out:
# CSV file successfully loaded. Columns: Index(['Unnamed: 0', 'Date', 'Open', 'High', 'Low', 'Close', 'Adj Close',
#        'Volume', 'daily_return', '20_day_ma', '50_day_ma'],
#       dtype='object')
# Scaler saved to outputs/nvidia_scale.pkl
# Data split: 554 training samples, 55 validation samples, 52 testing samples
# X_train shape: (554, 60, 1), y_train shape: (554, 1)
# X_train shape: (55, 60, 1), y_train shape: (55, 1)
# X_test shape: (52, 60, 1), y_test shape: (52, 1)
# X_train shape: (554, 60, 1)
# y_train shape: (554, 1)
# Input shape is valid: (554, 60, 1)
# Input shape is valid: (55, 60, 1)
# Epoch 1/50
# C:\Users\parth\mp_env\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 18/18 - 3s - 177ms/step - loss: 0.0178 - mean_absolute_error: 0.0937 - mean_absolute_percentage_error: 212554.8906 - symmetric_mean_absolute_percentage_error: 64.9931 - val_loss: 0.0601 - val_mean_absolute_error: 0.2399 - val_mean_absolute_percentage_error: 30.4815 - val_symmetric_mean_absolute_percentage_error: 35.8249
# Epoch 2/50
# 18/18 - 0s - 27ms/step - loss: 0.0036 - mean_absolute_error: 0.0470 - mean_absolute_percentage_error: 121533.5312 - symmetric_mean_absolute_percentage_error: 39.4111 - val_loss: 0.0022 - val_mean_absolute_error: 0.0345 - val_mean_absolute_percentage_error: 4.3087 - val_symmetric_mean_absolute_percentage_error: 4.3088
# Epoch 3/50
# 18/18 - 1s - 38ms/step - loss: 0.0024 - mean_absolute_error: 0.0343 - mean_absolute_percentage_error: 138153.2344 - symmetric_mean_absolute_percentage_error: 28.1629 - val_loss: 0.0041 - val_mean_absolute_error: 0.0549 - val_mean_absolute_percentage_error: 6.8383 - val_symmetric_mean_absolute_percentage_error: 7.1309
# Epoch 4/50
# 18/18 - 1s - 33ms/step - loss: 0.0017 - mean_absolute_error: 0.0286 - mean_absolute_percentage_error: 81272.7969 - symmetric_mean_absolute_percentage_error: 25.5217 - val_loss: 0.0054 - val_mean_absolute_error: 0.0651 - val_mean_absolute_percentage_error: 8.2194 - val_symmetric_mean_absolute_percentage_error: 8.5337
# Epoch 5/50
# 18/18 - 1s - 29ms/step - loss: 0.0019 - mean_absolute_error: 0.0291 - mean_absolute_percentage_error: 70388.7891 - symmetric_mean_absolute_percentage_error: 25.1764 - val_loss: 0.0020 - val_mean_absolute_error: 0.0345 - val_mean_absolute_percentage_error: 4.3770 - val_symmetric_mean_absolute_percentage_error: 4.2938
# Epoch 6/50
# 18/18 - 1s - 33ms/step - loss: 0.0024 - mean_absolute_error: 0.0327 - mean_absolute_percentage_error: 80112.8203 - symmetric_mean_absolute_percentage_error: 25.8288 - val_loss: 0.0066 - val_mean_absolute_error: 0.0735 - val_mean_absolute_percentage_error: 9.2713 - val_symmetric_mean_absolute_percentage_error: 9.6884
# Epoch 7/50
# 18/18 - 1s - 34ms/step - loss: 0.0020 - mean_absolute_error: 0.0289 - mean_absolute_percentage_error: 112862.2031 - symmetric_mean_absolute_percentage_error: 23.5554 - val_loss: 0.0013 - val_mean_absolute_error: 0.0258 - val_mean_absolute_percentage_error: 3.3300 - val_symmetric_mean_absolute_percentage_error: 3.2670
# Epoch 8/50
# 18/18 - 1s - 35ms/step - loss: 0.0021 - mean_absolute_error: 0.0290 - mean_absolute_percentage_error: 120331.4375 - symmetric_mean_absolute_percentage_error: 22.9972 - val_loss: 0.0034 - val_mean_absolute_error: 0.0504 - val_mean_absolute_percentage_error: 6.3680 - val_symmetric_mean_absolute_percentage_error: 6.5211
# Epoch 9/50
# 18/18 - 1s - 33ms/step - loss: 0.0015 - mean_absolute_error: 0.0256 - mean_absolute_percentage_error: 19868.6973 - symmetric_mean_absolute_percentage_error: 22.6761 - val_loss: 0.0035 - val_mean_absolute_error: 0.0506 - val_mean_absolute_percentage_error: 6.3102 - val_symmetric_mean_absolute_percentage_error: 6.5344
# Epoch 10/50
# 18/18 - 1s - 34ms/step - loss: 0.0013 - mean_absolute_error: 0.0240 - mean_absolute_percentage_error: 108525.0469 - symmetric_mean_absolute_percentage_error: 20.5147 - val_loss: 0.0020 - val_mean_absolute_error: 0.0342 - val_mean_absolute_percentage_error: 4.3296 - val_symmetric_mean_absolute_percentage_error: 4.2558
# Epoch 11/50
# 18/18 - 1s - 36ms/step - loss: 0.0015 - mean_absolute_error: 0.0265 - mean_absolute_percentage_error: 57571.2070 - symmetric_mean_absolute_percentage_error: 23.4220 - val_loss: 0.0021 - val_mean_absolute_error: 0.0367 - val_mean_absolute_percentage_error: 4.7582 - val_symmetric_mean_absolute_percentage_error: 4.5763
# Epoch 12/50
# 18/18 - 1s - 30ms/step - loss: 0.0016 - mean_absolute_error: 0.0273 - mean_absolute_percentage_error: 114292.4375 - symmetric_mean_absolute_percentage_error: 27.2359 - val_loss: 0.0015 - val_mean_absolute_error: 0.0291 - val_mean_absolute_percentage_error: 3.7771 - val_symmetric_mean_absolute_percentage_error: 3.6533
# Epoch 13/50
# 18/18 - 1s - 36ms/step - loss: 0.0013 - mean_absolute_error: 0.0244 - mean_absolute_percentage_error: 40059.2148 - symmetric_mean_absolute_percentage_error: 24.0186 - val_loss: 0.0052 - val_mean_absolute_error: 0.0647 - val_mean_absolute_percentage_error: 8.1186 - val_symmetric_mean_absolute_percentage_error: 8.4577
# Epoch 14/50
# 18/18 - 1s - 34ms/step - loss: 0.0018 - mean_absolute_error: 0.0280 - mean_absolute_percentage_error: 73826.6406 - symmetric_mean_absolute_percentage_error: 27.0445 - val_loss: 0.0052 - val_mean_absolute_error: 0.0650 - val_mean_absolute_percentage_error: 8.1431 - val_symmetric_mean_absolute_percentage_error: 8.4981
# Epoch 15/50
# 18/18 - 1s - 34ms/step - loss: 0.0017 - mean_absolute_error: 0.0273 - mean_absolute_percentage_error: 101820.9922 - symmetric_mean_absolute_percentage_error: 22.4923 - val_loss: 0.0039 - val_mean_absolute_error: 0.0552 - val_mean_absolute_percentage_error: 6.9533 - val_symmetric_mean_absolute_percentage_error: 7.1677
# Epoch 16/50
# 18/18 - 1s - 29ms/step - loss: 0.0011 - mean_absolute_error: 0.0241 - mean_absolute_percentage_error: 89286.0703 - symmetric_mean_absolute_percentage_error: 24.0175 - val_loss: 0.0014 - val_mean_absolute_error: 0.0274 - val_mean_absolute_percentage_error: 3.5164 - val_symmetric_mean_absolute_percentage_error: 3.4762
# Epoch 17/50
# 18/18 - 1s - 34ms/step - loss: 0.0015 - mean_absolute_error: 0.0267 - mean_absolute_percentage_error: 122265.0234 - symmetric_mean_absolute_percentage_error: 26.9975 - val_loss: 0.0012 - val_mean_absolute_error: 0.0246 - val_mean_absolute_percentage_error: 3.1758 - val_symmetric_mean_absolute_percentage_error: 3.1019
# Epoch 18/50
# 18/18 - 1s - 35ms/step - loss: 0.0014 - mean_absolute_error: 0.0264 - mean_absolute_percentage_error: 141984.5625 - symmetric_mean_absolute_percentage_error: 28.2461 - val_loss: 0.0013 - val_mean_absolute_error: 0.0249 - val_mean_absolute_percentage_error: 3.2135 - val_symmetric_mean_absolute_percentage_error: 3.1441
# Epoch 19/50
# 18/18 - 1s - 32ms/step - loss: 0.0015 - mean_absolute_error: 0.0255 - mean_absolute_percentage_error: 29874.6113 - symmetric_mean_absolute_percentage_error: 24.5774 - val_loss: 0.0055 - val_mean_absolute_error: 0.0675 - val_mean_absolute_percentage_error: 8.5395 - val_symmetric_mean_absolute_percentage_error: 8.8552
# Epoch 20/50
# 18/18 - 1s - 38ms/step - loss: 0.0012 - mean_absolute_error: 0.0260 - mean_absolute_percentage_error: 24250.0020 - symmetric_mean_absolute_percentage_error: 27.1045 - val_loss: 0.0013 - val_mean_absolute_error: 0.0261 - val_mean_absolute_percentage_error: 3.3528 - val_symmetric_mean_absolute_percentage_error: 3.3062
# Epoch 21/50
# 18/18 - 1s - 37ms/step - loss: 0.0013 - mean_absolute_error: 0.0257 - mean_absolute_percentage_error: 84833.2578 - symmetric_mean_absolute_percentage_error: 25.8225 - val_loss: 0.0014 - val_mean_absolute_error: 0.0264 - val_mean_absolute_percentage_error: 3.3801 - val_symmetric_mean_absolute_percentage_error: 3.3183
# Epoch 22/50
# 18/18 - 1s - 29ms/step - loss: 0.0012 - mean_absolute_error: 0.0232 - mean_absolute_percentage_error: 50528.3203 - symmetric_mean_absolute_percentage_error: 23.7144 - val_loss: 0.0015 - val_mean_absolute_error: 0.0297 - val_mean_absolute_percentage_error: 3.7886 - val_symmetric_mean_absolute_percentage_error: 3.7806
# Epoch 23/50
# 18/18 - 1s - 29ms/step - loss: 0.0012 - mean_absolute_error: 0.0242 - mean_absolute_percentage_error: 8362.5293 - symmetric_mean_absolute_percentage_error: 26.1394 - val_loss: 0.0097 - val_mean_absolute_error: 0.0924 - val_mean_absolute_percentage_error: 11.6233 - val_symmetric_mean_absolute_percentage_error: 12.3347
# Epoch 24/50
# 18/18 - 1s - 33ms/step - loss: 0.0014 - mean_absolute_error: 0.0264 - mean_absolute_percentage_error: 39198.7656 - symmetric_mean_absolute_percentage_error: 26.5942 - val_loss: 0.0038 - val_mean_absolute_error: 0.0538 - val_mean_absolute_percentage_error: 6.6769 - val_symmetric_mean_absolute_percentage_error: 6.9572
# Epoch 25/50
# 18/18 - 1s - 36ms/step - loss: 0.0011 - mean_absolute_error: 0.0239 - mean_absolute_percentage_error: 14468.5596 - symmetric_mean_absolute_percentage_error: 24.0957 - val_loss: 0.0012 - val_mean_absolute_error: 0.0253 - val_mean_absolute_percentage_error: 3.2630 - val_symmetric_mean_absolute_percentage_error: 3.1823
# Epoch 26/50
# 18/18 - 1s - 33ms/step - loss: 0.0014 - mean_absolute_error: 0.0253 - mean_absolute_percentage_error: 41097.1172 - symmetric_mean_absolute_percentage_error: 23.5384 - val_loss: 0.0015 - val_mean_absolute_error: 0.0293 - val_mean_absolute_percentage_error: 3.7505 - val_symmetric_mean_absolute_percentage_error: 3.7263
# Epoch 27/50
# 18/18 - 1s - 33ms/step - loss: 0.0013 - mean_absolute_error: 0.0252 - mean_absolute_percentage_error: 12771.4092 - symmetric_mean_absolute_percentage_error: 26.0479 - val_loss: 0.0046 - val_mean_absolute_error: 0.0605 - val_mean_absolute_percentage_error: 7.5439 - val_symmetric_mean_absolute_percentage_error: 7.8726
# Epoch 28/50
# 18/18 - 1s - 35ms/step - loss: 0.0017 - mean_absolute_error: 0.0257 - mean_absolute_percentage_error: 28879.9961 - symmetric_mean_absolute_percentage_error: 24.7507 - val_loss: 0.0024 - val_mean_absolute_error: 0.0405 - val_mean_absolute_percentage_error: 5.0657 - val_symmetric_mean_absolute_percentage_error: 5.1823
# Epoch 29/50
# 18/18 - 1s - 35ms/step - loss: 0.0016 - mean_absolute_error: 0.0261 - mean_absolute_percentage_error: 136664.8594 - symmetric_mean_absolute_percentage_error: 27.2729 - val_loss: 0.0012 - val_mean_absolute_error: 0.0254 - val_mean_absolute_percentage_error: 3.3265 - val_symmetric_mean_absolute_percentage_error: 3.2120
# Epoch 30/50
# 18/18 - 1s - 32ms/step - loss: 0.0016 - mean_absolute_error: 0.0275 - mean_absolute_percentage_error: 52756.1055 - symmetric_mean_absolute_percentage_error: 28.2634 - val_loss: 0.0015 - val_mean_absolute_error: 0.0293 - val_mean_absolute_percentage_error: 3.6976 - val_symmetric_mean_absolute_percentage_error: 3.7208
# Epoch 31/50
# 18/18 - 1s - 34ms/step - loss: 0.0013 - mean_absolute_error: 0.0247 - mean_absolute_percentage_error: 27602.7852 - symmetric_mean_absolute_percentage_error: 28.5911 - val_loss: 0.0013 - val_mean_absolute_error: 0.0262 - val_mean_absolute_percentage_error: 3.3311 - val_symmetric_mean_absolute_percentage_error: 3.3246
# Epoch 32/50
# 18/18 - 1s - 36ms/step - loss: 0.0014 - mean_absolute_error: 0.0244 - mean_absolute_percentage_error: 6870.2607 - symmetric_mean_absolute_percentage_error: 23.7088 - val_loss: 0.0076 - val_mean_absolute_error: 0.0802 - val_mean_absolute_percentage_error: 10.0018 - val_symmetric_mean_absolute_percentage_error: 10.6008
# Epoch 33/50
# 18/18 - 1s - 31ms/step - loss: 0.0015 - mean_absolute_error: 0.0256 - mean_absolute_percentage_error: 50428.9297 - symmetric_mean_absolute_percentage_error: 27.6515 - val_loss: 0.0032 - val_mean_absolute_error: 0.0487 - val_mean_absolute_percentage_error: 6.0336 - val_symmetric_mean_absolute_percentage_error: 6.2672
# Epoch 34/50
# 18/18 - 1s - 35ms/step - loss: 0.0018 - mean_absolute_error: 0.0269 - mean_absolute_percentage_error: 16639.2969 - symmetric_mean_absolute_percentage_error: 24.6117 - val_loss: 0.0057 - val_mean_absolute_error: 0.0689 - val_mean_absolute_percentage_error: 8.6696 - val_symmetric_mean_absolute_percentage_error: 9.0437
# Epoch 35/50
# 18/18 - 1s - 33ms/step - loss: 0.0014 - mean_absolute_error: 0.0242 - mean_absolute_percentage_error: 75957.2812 - symmetric_mean_absolute_percentage_error: 25.7060 - val_loss: 0.0019 - val_mean_absolute_error: 0.0347 - val_mean_absolute_percentage_error: 4.3493 - val_symmetric_mean_absolute_percentage_error: 4.4146
# Epoch 36/50
# 18/18 - 1s - 35ms/step - loss: 0.0012 - mean_absolute_error: 0.0251 - mean_absolute_percentage_error: 18122.3652 - symmetric_mean_absolute_percentage_error: 28.7971 - val_loss: 0.0023 - val_mean_absolute_error: 0.0398 - val_mean_absolute_percentage_error: 5.0507 - val_symmetric_mean_absolute_percentage_error: 5.1056
# Epoch 37/50
# 18/18 - 1s - 29ms/step - loss: 0.0012 - mean_absolute_error: 0.0251 - mean_absolute_percentage_error: 56103.4883 - symmetric_mean_absolute_percentage_error: 26.8522 - val_loss: 0.0015 - val_mean_absolute_error: 0.0299 - val_mean_absolute_percentage_error: 3.7552 - val_symmetric_mean_absolute_percentage_error: 3.7889
# Epoch 38/50
# 18/18 - 1s - 36ms/step - loss: 0.0010 - mean_absolute_error: 0.0227 - mean_absolute_percentage_error: 65322.0664 - symmetric_mean_absolute_percentage_error: 25.9110 - val_loss: 0.0023 - val_mean_absolute_error: 0.0399 - val_mean_absolute_percentage_error: 4.9441 - val_symmetric_mean_absolute_percentage_error: 5.1023
# Epoch 39/50
# 18/18 - 1s - 37ms/step - loss: 0.0014 - mean_absolute_error: 0.0260 - mean_absolute_percentage_error: 71893.5156 - symmetric_mean_absolute_percentage_error: 28.8167 - val_loss: 0.0039 - val_mean_absolute_error: 0.0552 - val_mean_absolute_percentage_error: 6.8946 - val_symmetric_mean_absolute_percentage_error: 7.1539
# Epoch 40/50
# 18/18 - 1s - 29ms/step - loss: 0.0012 - mean_absolute_error: 0.0241 - mean_absolute_percentage_error: 28959.9062 - symmetric_mean_absolute_percentage_error: 25.5602 - val_loss: 0.0012 - val_mean_absolute_error: 0.0265 - val_mean_absolute_percentage_error: 3.3632 - val_symmetric_mean_absolute_percentage_error: 3.3514
# Epoch 41/50
# 18/18 - 1s - 32ms/step - loss: 0.0013 - mean_absolute_error: 0.0258 - mean_absolute_percentage_error: 37372.2422 - symmetric_mean_absolute_percentage_error: 29.0478 - val_loss: 0.0020 - val_mean_absolute_error: 0.0374 - val_mean_absolute_percentage_error: 4.6659 - val_symmetric_mean_absolute_percentage_error: 4.7681
# Epoch 42/50
# 18/18 - 1s - 35ms/step - loss: 0.0013 - mean_absolute_error: 0.0250 - mean_absolute_percentage_error: 14341.1592 - symmetric_mean_absolute_percentage_error: 26.5946 - val_loss: 0.0029 - val_mean_absolute_error: 0.0465 - val_mean_absolute_percentage_error: 5.7903 - val_symmetric_mean_absolute_percentage_error: 5.9747
# Epoch 43/50
# 18/18 - 1s - 36ms/step - loss: 0.0011 - mean_absolute_error: 0.0230 - mean_absolute_percentage_error: 33228.5000 - symmetric_mean_absolute_percentage_error: 25.7367 - val_loss: 0.0018 - val_mean_absolute_error: 0.0341 - val_mean_absolute_percentage_error: 4.2178 - val_symmetric_mean_absolute_percentage_error: 4.3430
# Epoch 44/50
# 18/18 - 1s - 32ms/step - loss: 0.0013 - mean_absolute_error: 0.0236 - mean_absolute_percentage_error: 93952.3281 - symmetric_mean_absolute_percentage_error: 24.2298 - val_loss: 0.0040 - val_mean_absolute_error: 0.0560 - val_mean_absolute_percentage_error: 6.9686 - val_symmetric_mean_absolute_percentage_error: 7.2575
# Model saved to outputs/stock_price_lstm_nvidia_model.keras
# Model loaded from outputs/stock_price_lstm_nvidia_model.keras
# Scaler loaded from outputs/nvidia_scale.pkl
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# Predictions (rescaled): [[125.62396 ]
#  [125.32388 ]
#  [123.489746]
#  [125.01651 ]
#  [125.18297 ]
#  [121.71724 ]
#  [119.19839 ]
#  [118.00869 ]
#  [116.55509 ]
#  [112.370125]
#  [115.81444 ]
#  [113.86355 ]
#  [112.30714 ]
#  [108.521034]
#  [108.049484]
#  [105.2881  ]
#  [106.32851 ]
#  [106.57524 ]
#  [108.56852 ]
#  [112.66614 ]
#  [115.76325 ]
#  [119.749466]
#  [122.772545]
#  [125.79501 ]
#  [125.98276 ]
#  [127.5594  ]
#  [127.97948 ]
#  [124.76247 ]
#  [124.03765 ]
#  [118.476265]
#  [114.9024  ]
#  [113.0869  ]
#  [110.0046  ]
#  [109.80638 ]
#  [110.14959 ]
#  [114.062386]
#  [117.05701 ]
#  [118.861435]
#  [119.01377 ]
#  [118.73547 ]
#  [117.65773 ]
#  [119.049   ]
#  [118.838   ]
#  [118.95146 ]
#  [121.01265 ]
#  [123.2066  ]
#  [124.692444]
#  [124.44705 ]
#  [124.485664]
#  [122.54256 ]
#  [122.40495 ]
#  [123.93581 ]]
# 2/2 - 1s - 378ms/step - loss: 0.0029 - mean_absolute_error: 0.0436 - mean_absolute_percentage_error: 5.0240 - symmetric_mean_absolute_percentage_error: 4.4939
# loss: 0.0029
# compile_metrics: 0.0436
# SMAPE (manual, rescaled): 4.4029
